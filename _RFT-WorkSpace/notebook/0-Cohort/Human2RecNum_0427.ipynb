# %% [markdown]
# # Space

# %%
import os
import logging
import pandas as pd 
from IPython.display import display, HTML
KEY = 'WorkSpace'
WORKSPACE_PATH = os.getcwd().split(KEY)[0] + KEY
print(WORKSPACE_PATH)
os.chdir(WORKSPACE_PATH)

import sys
sys.path.append(WORKSPACE_PATH)
from proj_space import PROJECT, TaskName, SPACE
SPACE['WORKSPACE_PATH'] = WORKSPACE_PATH
sys.path.append(SPACE['CODE_FN'])

recfldtkn_config_path = os.path.join(SPACE['CODE_FN'], 'config_recfldtkn/')

logger = logging.getLogger(__name__)
logging.basicConfig(level=logging.INFO, format='[%(levelname)s:%(asctime)s:(%(filename)s@%(lineno)d %(name)s)]: %(message)s')
# Out:
# g:\Shared drives\CDHAI-WellDoc\2024-WellDocTest-SPACE\_WellDoc-RFT-WorkSpace

# %% [markdown]
# # [Part 1]: develop fn_humanrec.py

# %% [markdown]
# ## [Step 1]: Create Cohort Yaml

# %%
# Create a HTML link and display it
path = os.path.join(recfldtkn_config_path, 'Cohort.yaml')
full_path = os.path.join(WORKSPACE_PATH, path)
display(HTML(f'{path} <a href="{full_path}" target="_blank">Open File</a>'))
# Out:
# ../pipeline\config_recfldtkn/Cohort.yaml <a href="g:\Shared drives\CDHAI-WellDoc\2024-WellDocTest-SPACE\_WellDoc-RFT-WorkSpace\../pipeline\config_recfldtkn/Cohort.yaml" target="_blank">Open File</a>

# %% [markdown]
# ## [Step 2]: Update Cohort Yaml

# %% [markdown]
# **Template**
#
# ```yaml
# # %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%  the folders where to save the data
# CohortInfo:
#   COHORT_NAME_XXXXXX: # <---- change this.
#     cohort_label: 1
#     FolderPath: $DATA_RAW$/COHORT_NAME_XXXXXX
#
# # %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%  where to get the raw Human data.
# RawRootID: 'XXXXXXXXX' # <--- HumanID in Raw Data.
# RootID:  'XXXXXXXXX'        # <--- HumanID in RFT Data.
# ```

# %%
display(HTML(f'{path} <a href="{full_path}" target="_blank">Open File</a>'))
# Out:
# ../pipeline\config_recfldtkn/Cohort.yaml <a href="g:\Shared drives\CDHAI-WellDoc\2024-WellDocTest-SPACE\_WellDoc-RFT-WorkSpace\../pipeline\config_recfldtkn/Cohort.yaml" target="_blank">Open File</a>

# %% [markdown]
# ## [Step 3] Cohort: Pick OneCohort

# %%
################### in notebook ###################  
args_information = ['--cohort_label', '3'] # < ------- change here
###################################################

# %%
import argparse
from recfldtkn.configfn import load_cohort_args

cohort_args = load_cohort_args(recfldtkn_config_path, SPACE)

my_parser = argparse.ArgumentParser(description='Process Input.')

my_parser.add_argument('--cohort_name',
                    metavar='cohort_name',
                    default = None, 
                    type=str,
                    help='the cohort_name to process')

my_parser.add_argument('--cohort_label',
                    metavar='cohort_label',
                    default = None, 
                    type=str,
                    help='the label for cohort_name to process')

args = my_parser.parse_args(args_information)

cohort_label = int(args.cohort_label)
cohort_name = [v for k, v in cohort_args['CohortInfo'].items() 
               if v['cohort_label'] == cohort_label][0]['cohort_name']

print(f'=============== {cohort_name}: {cohort_label} ======================')
print(cohort_name, cohort_label)
# Out:
# =============== RawData2023_CVSDeRxAug: 3 ======================
# RawData2023_CVSDeRxAug 3

# %% [markdown]
# ## [Step 4] OneCohort_Args

# %%
OneCohort_Args = cohort_args['CohortInfo'][cohort_name]
OneCohort_Args
# Out:
# {'cohort_label': 3,
#  'cohort_name': 'RawData2023_CVSDeRxAug',
#  'FolderPath': '../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/'}

# %%
os.listdir(OneCohort_Args['FolderPath'])
# Out:
# ['08_23_2023_MedAdministration.csv',
#  '08_23_2023_CustomFood.csv',
#  '08_23_2023_RecentElogBGEntry.csv',
#  '08_23_2023_ImportedMedication.csv',
#  '08_23_2023_ELogCarbsEntry.csv',
#  '08_23_2023_CurriculumLessonProgressDetails.csv',
#  '08_23_2023_CurriculumTopicProgressDetails.csv',
#  '08_23_2023_CurriculumQuizResponse.csv',
#  '08_23_2023_SleepEntry.csv',
#  '08_23_2023_ElogKetoneEntry.csv',
#  '08_23_2023_ElogBPEntry.csv',
#  '08_23_2023_PatientReminder.csv',
#  '08_23_2023_PatientLabTestResult.csv',
#  '08_23_2023_Patient.csv',
#  '08_23_2023_PatientTargetSegment.csv',
#  '08_23_2023_UserDetail.csv',
#  '08_23_2023_PatientBloodGlucoseTargets.csv',
#  '08_23_2023_CurriculumSurveyResponse.csv',
#  '08_23_2023_ELogSymptomTracker.csv',
#  '08_23_2023_FavoriteFood.csv',
#  '08_23_2023_StepEntry.csv',
#  '08_23_2023_WeightMeter.csv',
#  '08_23_2023_WeightGoal.csv',
#  '08_23_2023_ElogBGEntry.csv',
#  '08_23_2023_ElogWeightEntry.csv',
#  '08_23_2023_ELogExerciseEntry.csv',
#  '08_31_2023_DSMQuestionAnswer_CVS_Pull_De_Rx.csv',
#  '08_23_2023_ELogCommentEntry.csv',
#  '08_23_2023_CurriculumQuizResult.csv',
#  '08_23_2023_PatientLastExam.csv',
#  '08_23_2023_PatientCarbTarget.csv',
#  '08_23_2023_PatientObservationSummary.csv',
#  '08_23_2023_CurriculumCourseProgressDetails.csv',
#  '08_23_2023_MedPrescription.csv',
#  '08_23_2023_ELogFoodItem.csv',
#  '08_23_2023_PatientMeal.csv',
#  '08_23_2023_PatientMeter.csv',
#  '08_23_2023_BPMeter.csv',
#  '08_23_2023_PatientHeight.csv',
#  '08_23_2023_CurriculumCourseBadgeDetails.csv',
#  '08_23_2023_MedPrescriptionDaySchedule.csv']

# %% [markdown]
# ## [Step 5] selected_source_file_suffix_list

# %%
#########################
selected_source_file_suffix_list = ['csv']
#########################


# this step will be conducted within the pipeline
selected_file_list = [file for file in os.listdir(OneCohort_Args['FolderPath']) 
                      if file.endswith(tuple(selected_source_file_suffix_list))]
print(len(selected_file_list))
# Out:
# 41

# %%
selected_file_list[:10]
# Out:
# ['08_23_2023_MedAdministration.csv',
#  '08_23_2023_CustomFood.csv',
#  '08_23_2023_RecentElogBGEntry.csv',
#  '08_23_2023_ImportedMedication.csv',
#  '08_23_2023_ELogCarbsEntry.csv',
#  '08_23_2023_CurriculumLessonProgressDetails.csv',
#  '08_23_2023_CurriculumTopicProgressDetails.csv',
#  '08_23_2023_CurriculumQuizResponse.csv',
#  '08_23_2023_SleepEntry.csv',
#  '08_23_2023_ElogKetoneEntry.csv']

# %% [markdown]
# ## [Step 6] Map Raw Table file to Raw Table name
#
#
# TODO:
#
#
# eg: '05_12_2022_PatientCGMDeviceDetail.csv' to 'PatientCGMDeviceDetail'

# %%
import inspect
#########################
def get_tablename_from_raw_filename(file_path):
    # name = file_path.split('/')[-1].split('_df_')[0]
    tablename = file_path.split('_')[-1].split('.')[0]
    return tablename

get_tablename_from_raw_filename.fn_string = inspect.getsource(get_tablename_from_raw_filename)
#########################

# %%
file_path = selected_file_list[0]

tablename = get_tablename_from_raw_filename(file_path)
print(file_path)
print(tablename)
# Out:
# 08_23_2023_MedAdministration.csv
# MedAdministration

# %%
# TODO: add loop

# %% [markdown]
# ## [Step 7]: get_rawrootid_column
#
#
# TODO:

# %%
##################################################
def get_rawrootid_from_raw_table_column(raw_table_columns):
    rawrootid = None 
    if 'PatientID' in raw_table_columns: 
        rawrootid = 'PatientID' 
    if 'UserID' in raw_table_columns:
        rawrootid = 'UserID'
    if 'PatientId' in raw_table_columns: 
        rawrootid = 'PatientId' 

    return rawrootid

get_rawrootid_from_raw_table_column.fn_string = inspect.getsource(get_rawrootid_from_raw_table_column)
##################################################

# %%
# interpret the code. 
for file_path in selected_file_list:
    print('\n')
    full_path = os.path.join(OneCohort_Args['FolderPath'], file_path)
    if full_path.endswith('.csv'):
        print(file_path, '<--- raw_table_columns')
        try:
            df = pd.read_csv(full_path, nrows=5)
            raw_table_columns = df.columns.tolist()
            print(raw_table_columns, '<--- file_path')
            rawrootid = get_rawrootid_from_raw_table_column(raw_table_columns)
            print(rawrootid, '<--- rawrootid')

        except:
            print(f'Error reading {full_path}')
            continue 
    

    elif full_path.endswith('.p'):
        raise ValueError(f'.p is not supported: {full_path}')
    
    else:
        raise ValueError(f'file type not supported: {full_path}')
# Out:
# 08_23_2023_MedAdministration.csv <--- raw_table_columns
# ['AdministrationID', 'ELogEntryID', 'AdministrationDate', 'ActivityTypeID', 'Dose', 'MedSourceID', 'StatusID', 'EntryDateTime', 'CreatedDate', 'CreatedBy', 'RowVersionID', 'PatientID', 'MedPrescriptionID', 'AdministrationTimeZoneOffset', 'AdministrationTimeZone', 'PrescriptionGUID', 'MedAdministrationID', 'MedPrescriptionTime', 'MedicationID', 'AdministrationTimeLabelID', 'AdminSlot', 'ScheduledSlot', 'ModifiedDateTime', 'UserAdministrationDate', 'BGValue', 'CarbsValue', 'InsulinCalculatorUsageStatus', 'IOBValue', 'FoodInsulinDose', 'ExternalEntryID'] <--- file_path
# PatientID <--- rawrootid
#
#
# 08_23_2023_CustomFood.csv <--- raw_table_columns
# ['CustomFoodID', 'PatientID', 'CustomFoodGUID', 'FoodName', 'CarbsValue', 'ServingType', 'ServingSize', 'StatusID', 'EntrySourceID', 'EntryDateTime', 'CreatedDate', 'ModifiedDate', 'RowVersionID', 'Fiber', 'Fat', 'Calories', 'Protein', 'Sodium', 'LastModifiedBy'] <--- file_path
# PatientID <--- rawrootid
#
#
# 08_23_2023_RecentElogBGEntry.csv <--- raw_table_columns
# ['PatientID', 'EntryID', 'ObservationDateTime', 'BGValue', 'ParentEntryID', 'ActivityTypeID', 'ObservationEntryDateTime', 'TimezoneOffset', 'Timezone', 'EntrySourceID', 'ObservationStatus', 'ExternalEntryID', 'RowVersionID'] <--- file_path
# PatientID <--- rawrootid
#
#
# 08_23_2023_ImportedMedication.csv <--- raw_table_columns
# Error reading ../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_ImportedMedication.csv
#
#
# 08_23_2023_ELogCarbsEntry.csv <--- raw_table_columns
# ['CarbsEntryID', 'PatientID', 'EntryID', 'CarbsValue', 'EntrySourceID', 'ActivityTypeID', 'ObservationDateTime', 'ObservationEntryDateTime', 'TimezoneOffset', 'Timezone', 'EntryCreatedDateTime', 'ObservationCreatedBy', 'ObservationStatus', 'RowVersionID', 'SourceReferenceID', 'ModifiedDateTime', 'ExternalSourceID', 'ExternalEntryID', 'TotalCalories'] <--- file_path
# PatientID <--- rawrootid
#
#
# 08_23_2023_CurriculumLessonProgressDetails.csv <--- raw_table_columns
# ['CurriculumLessonProgressID', 'PatientID', 'TopicID', 'CourseID', 'LessonID', 'Status', 'RowVersionID', 'CreatedDateTime', 'ModifiedDateTime', 'LessonParentID'] <--- file_path
# PatientID <--- rawrootid
#
#
# 08_23_2023_CurriculumTopicProgressDetails.csv <--- raw_table_columns
# ['CurriculumTopicProgressID', 'PatientID', 'TopicID', 'Status', 'RowVersionID', 'CreatedDateTime', 'ModifiedDateTime'] <--- file_path
# PatientID <--- rawrootid
#
#
# 08_23_2023_CurriculumQuizResponse.csv <--- raw_table_columns
# ['QuizResponseID', 'QuizID', 'PatientID', 'QuestionID', 'AnswerID', 'StatusID', 'RowVersionID', 'CreatedDateTime', 'ModifiedDateTime', 'CompletedDateTime', 'QuizResultID'] <--- file_path
# PatientID <--- rawrootid
#
#
# 08_23_2023_SleepEntry.csv <--- raw_table_columns
# ['SleepEntryID', 'PatientID', 'EntryID', 'StartDateTime', 'EndDateTime', 'ObservationEntryDateTime', 'TimezoneOffset', 'Timezone', 'EntrySourceID', 'ObservationCreatedBy', 'ObservationStatus', 'CreatedDateTime', 'ModifiedDateTime', 'RowVersionID', 'DeepSleep', 'ExternalEntryID'] <--- file_path
# PatientID <--- rawrootid
#
#
# 08_23_2023_ElogKetoneEntry.csv <--- raw_table_columns
# ['KetoneEntryID', 'PatientID', 'EntryID', 'KetoneValue', 'MeasurementSourceID', 'ObservationDateTime', 'TimezoneOffset', 'Timezone', 'ObservationEntryDateTime', 'EntrySourceID', 'ObservationStatus', 'ExternalEntryID', 'ExternalSourceID', 'RowVersionID', 'CreatedDateTime', 'ModifiedDateTime', 'MeterType', 'IsFeedbackShown', 'SourceReferenceID', 'ObservationCreatedBy', 'Notes'] <--- file_path
# PatientID <--- rawrootid
#
#
# 08_23_2023_ElogBPEntry.csv <--- raw_table_columns
# ['BPEntryID', 'PatientID', 'EntryID', 'SBPValue', 'DBPValue', 'MeasurementSourceID', 'ObservationDateTime', 'TimezoneOffset', 'Timezone', 'ObservationEntryDateTime', 'EntrySourceID', 'ObservationStatus', 'ExternalEntryID', 'ExternalSourceID', 'RowVersionID', 'CreatedDateTime', 'ModifiedDateTime', 'HeartRateValue', 'MeterType', 'IsFeedbackShown', 'SourceReferenceID', 'ObservationCreatedBy'] <--- file_path
# PatientID <--- rawrootid
#
#
# 08_23_2023_PatientReminder.csv <--- raw_table_columns
# ['PatientReminderID', 'ReminderID', 'PatientID', 'Type', 'ReminderMappingID', 'StartDate', 'Frequency', 'ReminderTime', 'ReminderSlot', 'IsReminderOn', 'StatusID', 'CreatedDate', 'ModifiedDate', 'RowVersionID', 'EndDate', 'OutsideAppTitle', 'OutsideAppDescription', 'InsideAppTitle', 'InsideAppDescription'] <--- file_path
# PatientID <--- rawrootid
#
#
# 08_23_2023_PatientLabTestResult.csv <--- raw_table_columns
# ['PatientLabTestResultID', 'PatientID', 'ObservationDefinationID', 'OrderEntryID', 'EntrySourceID', 'IsNormalIndicator', 'PatientLabTestResultValue', 'ObservationUOMID', 'PatientLabTestResultRecordDate', 'PatientLabTestResultCreatedDate', 'PatientLabTestResultStatus', 'PatientLabTestResultCreatedBy', 'ObservationModifiedDate', 'RowVersionID', 'LabTestResultTimeZoneOffset', 'LabTestResultTimeZone', 'LabParentID', 'IsFeedbackShown'] <--- file_path
# PatientID <--- rawrootid
#
#
# 08_23_2023_Patient.csv <--- raw_table_columns
# ['PatientID', 'PatientRegistrationPageID', 'AlertSystemEnabled', 'PatientLastMobileActivationID', 'MaritalStatusID', 'RaceID', 'EthinicityID', 'IsEligible', 'MedicationReminderEnabled', 'AppointmentReminderEnabled', 'PatientCreatedDate', 'PatientModifiedDate', 'RowVersionID', 'MedicationViewMode', 'InPersonTrainingStatus', 'InPersonTrainingStatusDatetime', 'InPersonTrainingContactNumber', 'InPersonTrainingScheduledSlot', 'IsRefillRequired', 'IsRefillRequiredAnsweredDate', 'PAPEligibility', 'PAPStatus', 'PAPStatusReason', 'MRSegmentID', 'RefillReason', 'LastPushNotificationID', 'LastPushNotificationDate', 'IsTermsAgreed', 'NextWeeklyReportGeneratedDatetime', 'AllowMarketingMessages', 'IsWeeklyChallengeStartShown', 'WeeklyChallengeCount', 'IsWeeklyChallengeTwelveWeekShown', 'MRSegmentModifiedDateTime', 'IsWeeklyChallengeEnabled', 'NextWeeklyReportGeneratedTimeZoneOffset', 'NextEmailReminderCheckDateTime', 'RxRefillNotificationCheckDateTime', 'TrendingMessageLatestTriggerDate', 'FastingTrendingMessageLatestTriggerDate', 'IsEmailUnSubscribed', 'BGUOMID', 'HeightUOMID', 'WeightUOMID', 'IsBPIntroShown', 'DistanceUOMID', 'ExternalPatientCode', 'OnboardingStepId', 'IsWelcomeEmailSend', 'ChallengeNoEngagementEmailId', 'NonChallengeNoEngagementEmailId', 'LastNoEngagementEmailSentDateTime', 'IsSVReportReminderEmailSend', 'IsNoEngagementEmailStopped', 'DiseaseType', 'IsIOBEnabled', 'IOBChangedDate', 'IsInsulinAdded', 'IsCGMConnected', 'NextDailyReportGeneratedDatetime', 'ExternalPatientCodeHashed', 'PrescribedDIA', 'LevelOfEducationID', 'IDCQuizAnswers', 'IDCQuizRespondedDateTime', 'TitrationMode', 'IsTermsAgreedDateTime', 'IsSharePersonalInfoAgreed', 'IsSharePersonalInfoAgreedDateTime', 'TitrationType', 'ESIInvitationCode', 'IsPregnant', 'DiseaseCombinationID', 'IsTextMessagesTermsAndConditionsAgreedDateTime', 'IsEmailMessagesTermsAndConditionsAgreedDateTime', 'AllowSMS', 'IsTwoWayChatTermsAgreed', 'IsTwoWayChatTermsAgreedDateTime', 'PermissionForCustomerToContactViaText', 'PermissionForCustomerToContactViaEmail', 'EligibilityDiabetesYN', 'IsMemberDeactivationPopupViewed', 'WhereDidYouHearUsResponse', 'IsMemberDeactivatedWithOneDayLeftPopupViewed'] <--- file_path
# PatientID <--- rawrootid
#
#
# 08_23_2023_PatientTargetSegment.csv <--- raw_table_columns
# ['PatientID', 'ObservationTargetSegment', 'LastModifiedDateTime', 'RowVersionID', 'A1cTarget', 'BPTarget', 'KetoneThreshold'] <--- file_path
# PatientID <--- rawrootid
#
#
# 08_23_2023_UserDetail.csv <--- raw_table_columns
# ['UserID', 'RoleID', 'UserFirstName', 'UserMiddleName', 'UserLastName', 'DateOfBirth', 'Gender', 'TitleID', 'SuffixID', 'StatusID', 'StatusReason', 'EntrySourceID', 'UserEmail', 'UserEmailHashed', 'ExternalSystemUserID', 'RegistrationCompletedDate', 'RegistrationCompletedTimeZoneOffset', 'RegistrationCompletedTimeZone', 'ActivationDate', 'ActivationDateTimeZoneOffset', 'ActivationDateTimeZone', 'CreatedDate', 'ModifiedDate', 'UserSkey', 'RowVersionID', 'CellPhoneNumber', 'FeatureProfileID', 'SystemUserID', 'SystemAccessCode', 'PatientAuthorization', 'TrainingCompletedDate', 'IsTrainingSkipped', 'UserNickName', 'UpdateSourceID', 'FirstNameHashed', 'LastNameHashed', 'PatientDrivenRegistrationDate', 'PatientDrivenRegistrationDateTimeZoneOffset', 'PatientDrivenRegistrationDateTimeZone', 'RegisteredSourceID', 'AccountID', 'UserTimeZoneOffset', 'UserTimeZone', 'Description', 'YearOfBirth', 'RxRefillCheckDateTime', 'Language', 'Country', 'ExternalUserID', 'CommunityConsentDateTime', 'RecipeCommentConsentDateTime', 'ProfileLookupID', 'FullNameHashed', 'LastDataDownloadTriggerDateTime', 'DailyReportStartDate', 'DailyReportEndDate', 'DiseaseConditionID', 'SubDiseaseConditionID', 'DOBHashed', 'EligibilityProgram'] <--- file_path
# UserID <--- rawrootid
#
#
# 08_23_2023_PatientBloodGlucoseTargets.csv <--- raw_table_columns
# ['PatientID', 'PatientBGBeforeMealMin', 'PatientBGBeforeMealMax', 'PatientBGAfterMealMin', 'PatientBGAfterMealMax', 'PatientBGBedTimeMin', 'PatientBGBedTimeMax', 'PatientBGCreatedDate', 'PatientBGModifiedDate'] <--- file_path
# PatientID <--- rawrootid
#
#
# 08_23_2023_CurriculumSurveyResponse.csv <--- raw_table_columns
# ['SurveyResponseID', 'SurveyID', 'PatientID', 'QuestionID', 'AnswerID', 'AnswerText', 'StatusID', 'RowVersionID', 'CreatedDateTime', 'ModifiedDateTime', 'CompletedDateTime'] <--- file_path
# PatientID <--- rawrootid
#
#
# 08_23_2023_ELogSymptomTracker.csv <--- raw_table_columns
# Error reading ../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_ELogSymptomTracker.csv
#
#
# 08_23_2023_FavoriteFood.csv <--- raw_table_columns
# Error reading ../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_FavoriteFood.csv
#
#
# 08_23_2023_StepEntry.csv <--- raw_table_columns
# ['StepEntryID', 'PatientID', 'EntryID', 'NumberOfSteps', 'CaloriesBurned', 'DistanceInMeters', 'StartDateTime', 'EndDateTime', 'ObservationEntryDateTime', 'TimezoneOffset', 'Timezone', 'EntrySourceID', 'ObservationCreatedBy', 'ObservationStatus', 'CreatedDateTime', 'ModifiedDateTime', 'RowVersionID', 'ExternalEntryID'] <--- file_path
# PatientID <--- rawrootid
#
#
# 08_23_2023_WeightMeter.csv <--- raw_table_columns
# Error reading ../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_WeightMeter.csv
#
#
# 08_23_2023_WeightGoal.csv <--- raw_table_columns
# ['WeightGoalID', 'PatientID', 'EntryID', 'StartDate', 'Timezone', 'TimezoneOffset', 'TargetWeight', 'StartWeight', 'RecentWeight', 'ClosestToTargetWeight', 'Type', 'Status', 'TargetReachedDate', 'EntrySourceID', 'CreatedDateTime', 'ModifiedDateTime', 'RowVersionID'] <--- file_path
# PatientID <--- rawrootid
#
#
# 08_23_2023_ElogBGEntry.csv <--- raw_table_columns
# ['BGEntryID', 'PatientID', 'EntryID', 'ObservationDateTime', 'BGValue', 'IsNormalIndicator', 'ParentEntryID', 'ActivityTypeID', 'ObservationEntryDateTime', 'TimezoneOffset', 'Timezone', 'BGRecheckStartTime', 'BGRecheckDuration', 'EntrySourceID', 'EntryCreatedDateTime', 'ObservationCreatedBy', 'ObservationStatus', 'RowVersionID', 'MeterType', 'IsFeedbackShown', 'SourceReferenceID', 'ModifiedDateTime', 'ObservationUOMID', 'ExternalEntryID', 'BGCode', 'ActualBGValue', 'ExternalSourceID', 'UserObservationDateTime'] <--- file_path
# PatientID <--- rawrootid
#
#
# 08_23_2023_ElogWeightEntry.csv <--- raw_table_columns
# ['WeightEntryID', 'PatientID', 'EntryID', 'Weight', 'WeightUOMID', 'MeasurementSourceID', 'ObservationDateTime', 'TimezoneOffset', 'Timezone', 'ObservationEntryDateTime', 'EntrySourceID', 'ObservationStatus', 'OrderEntryID', 'ExternalSourceID', 'CreatedDateTime', 'ModifiedDateTime', 'RowVersionID', 'ExternalEntryID', 'MeterType', 'IsFeedbackShown', 'SourceReferenceID', 'ObservationCreatedBy', 'UserID', 'RoleID', 'UserFirstName', 'UserMiddleName', 'UserLastName', 'DateOfBirth', 'Gender', 'TitleID', 'SuffixID', 'StatusID', 'StatusReason', 'EntrySourceID1', 'UserEmail', 'UserEmailHashed', 'ExternalSystemUserID', 'RegistrationCompletedDate', 'RegistrationCompletedTimeZoneOffset', 'RegistrationCompletedTimeZone', 'ActivationDate', 'ActivationDateTimeZoneOffset', 'ActivationDateTimeZone', 'CreatedDate', 'ModifiedDate', 'UserSkey', 'RowVersionID1', 'CellPhoneNumber', 'FeatureProfileID', 'SystemUserID', 'SystemAccessCode', 'PatientAuthorization', 'TrainingCompletedDate', 'IsTrainingSkipped', 'UserNickName', 'UpdateSourceID', 'FirstNameHashed', 'LastNameHashed', 'PatientDrivenRegistrationDate', 'PatientDrivenRegistrationDateTimeZoneOffset', 'PatientDrivenRegistrationDateTimeZone', 'RegisteredSourceID', 'AccountID', 'UserTimeZoneOffset', 'UserTimeZone', 'Description', 'YearOfBirth', 'RxRefillCheckDateTime', 'Language', 'Country', 'ExternalUserID', 'CommunityConsentDateTime', 'RecipeCommentConsentDateTime', 'ProfileLookupID', 'FullNameHashed', 'LastDataDownloadTriggerDateTime', 'DailyReportStartDate', 'DailyReportEndDate', 'DiseaseConditionID', 'SubDiseaseConditionID', 'DOBHashed', 'EligibilityProgram'] <--- file_path
# UserID <--- rawrootid
#
#
# 08_23_2023_ELogExerciseEntry.csv <--- raw_table_columns
# ['ExerciseEntryID', 'PatientID', 'EntryID', 'ExerciseDuration', 'ExerciseType', 'ExerciseIntensity', 'TimeSinceExercise', 'EntrySourceID', 'ActivityTypeID', 'ObservationDateTime', 'ObservationEntryDateTime', 'TimezoneOffset', 'Timezone', 'EntryCreatedDateTime', 'ObservationCreatedBy', 'ObservationStatus', 'RowVersionID', 'SourceReferenceID', 'ModifiedDateTime', 'CaloriesBurned', 'DistanceInMeters', 'ExternalEntryID', 'ExternalSourceID'] <--- file_path
# PatientID <--- rawrootid
#
#
# 08_31_2023_DSMQuestionAnswer_CVS_Pull_De_Rx.csv <--- raw_table_columns
# ['ID', 'PatientID', 'ContainerID', 'QuestionID', 'ValueID', 'Value', 'SourceID', 'RowversionID', 'StatusID', 'CreatedDate', 'ModifiedDate', 'UserID', 'RoleID', 'UserFirstName', 'UserMiddleName', 'UserLastName', 'DateOfBirth', 'Gender', 'TitleID', 'SuffixID', 'StatusID1', 'StatusReason', 'EntrySourceID', 'UserEmail', 'UserEmailHashed', 'ExternalSystemUserID', 'RegistrationCompletedDate', 'RegistrationCompletedTimeZoneOffset', 'RegistrationCompletedTimeZone', 'ActivationDate', 'ActivationDateTimeZoneOffset', 'ActivationDateTimeZone', 'CreatedDate1', 'ModifiedDate1', 'UserSkey', 'RowVersionID1', 'CellPhoneNumber', 'FeatureProfileID', 'SystemUserID', 'SystemAccessCode', 'PatientAuthorization', 'TrainingCompletedDate', 'IsTrainingSkipped', 'UserNickName', 'UpdateSourceID', 'FirstNameHashed', 'LastNameHashed', 'PatientDrivenRegistrationDate', 'PatientDrivenRegistrationDateTimeZoneOffset', 'PatientDrivenRegistrationDateTimeZone', 'RegisteredSourceID', 'AccountID', 'UserTimeZoneOffset', 'UserTimeZone', 'Description', 'YearOfBirth', 'RxRefillCheckDateTime', 'Language', 'Country', 'ExternalUserID', 'CommunityConsentDateTime', 'RecipeCommentConsentDateTime', 'ProfileLookupID', 'FullNameHashed', 'LastDataDownloadTriggerDateTime', 'DailyReportStartDate', 'DailyReportEndDate', 'DiseaseConditionID', 'SubDiseaseConditionID', 'DOBHashed', 'EligibilityProgram'] <--- file_path
# UserID <--- rawrootid
#
#
# 08_23_2023_ELogCommentEntry.csv <--- raw_table_columns
# ['CommnetEntryID', 'PatientID', 'CommentID', 'EntryID', 'CommentEntryFreeText', 'EntrySourceID', 'ActivityTypeID', 'ObservationDateTime', 'ObservationEntryDateTime', 'TimezoneOffset', 'Timezone', 'EntryCreatedDateTime', 'ObservationCreatedBy', 'ObservationStatus', 'RowVersionID', 'SourceReferenceID', 'ModifiedDateTime'] <--- file_path
# PatientID <--- rawrootid
#
#
# 08_23_2023_CurriculumQuizResult.csv <--- raw_table_columns
# ['QuizResultID', 'QuizID', 'PatientID', 'QuizScorePercentage', 'StatusID', 'RowVersionID', 'CreatedDateTime', 'ModifiedDateTime'] <--- file_path
# PatientID <--- rawrootid
#
#
# 08_23_2023_PatientLastExam.csv <--- raw_table_columns
# ['PatientLastExamID', 'PatientID', 'ObservationDefinationID', 'OrderEntryID', 'EntrySourceID', 'IsNormalIndicator', 'PatientLastExamDate', 'ExamTypeAnswerID', 'PatientLastExamStatus', 'PatientLastExamCreatedBy', 'ObservationCreatedDate', 'ObservationModifiedDate', 'RowVersionID', 'LastExamTimeZoneOffset', 'LastExamTimeZone', 'ExamValue'] <--- file_path
# PatientID <--- rawrootid
#
#
# 08_23_2023_PatientCarbTarget.csv <--- raw_table_columns
# ['PatientID', 'ActivityTypeID', 'LowerRange', 'UpperRange', 'StatusID', 'UpdateSourceID', 'CreatedDateTime', 'ModifiedDateTime', 'RowVersionID'] <--- file_path
# PatientID <--- rawrootid
#
#
# 08_23_2023_PatientObservationSummary.csv <--- raw_table_columns
# ['PatientID', 'A1CLatestRecordedDate', 'A1CLatestValue', 'A1CLatestOutOfTargetRecordedDate', 'BPLatestRecordedDate', 'SysBPLatestValue', 'DiaBPLatestValue', 'BPLatestOutOfTargetRecordedDate', 'LDLLatestRecordedDate', 'LDLLatestValue', 'LDLLatestOutOfTargetRecordedDate', 'SVReportLatestGeneratedDate', 'BGHypoLatestRecordedDate', 'BGHyperLatestRecordedDate', 'BGLatestRecordedDate', 'MedicationLatestRecordedDate', 'CarbLatestRecordedDate', 'ActivityLatestRecordedDate', 'SleepLatestRecordedDate', 'RowVersionID', 'MeterLastSyncDateTime', 'BGFromMeterLatestRecordedDate', 'BGPerDayAverage', 'BGAverage', 'HypoBGCount', 'HyperBGCount', 'LastQuartzExecutionDateTime', 'LastLogin', 'A1CTarget', 'DeviceAppID', 'EyeExamLatestRecordedDate', 'FootExamLatestRecordedDate', 'InsulinCalculatorStatus', 'InsulinCalculatorStatusDateTime', 'InsulinCalculatorStatusCount', 'Language', 'WeightLatestValue', 'WeightLatestRecordedDate', 'HDLLatestValue', 'HDLLatestRecordedDate', 'HDLLatestOutOfTargetRecordedDate', 'StartWeight', 'GoalWeight', 'CurriculumCompletionStatus', 'ActivityTrackerLastSyncDateTime', 'MakeupCourseIDs', 'BGLatestRecordedUTCDate', 'LatestBGValue', 'LatestKetoneRecordedDate'] <--- file_path
# PatientID <--- rawrootid
#
#
# 08_23_2023_CurriculumCourseProgressDetails.csv <--- raw_table_columns
# ['CurriculumCourseProgressID', 'PatientID', 'TopicID', 'CourseID', 'Status', 'RowVersionID', 'CreatedDateTime', 'ModifiedDateTime'] <--- file_path
# PatientID <--- rawrootid
#
#
# 08_23_2023_MedPrescription.csv <--- raw_table_columns
# ['MedPrescriptionID', 'PatientID', 'MedicationID', 'FrequencyType', 'FrequencyValue', 'StartDate', 'StatusID', 'ValidationStatusID', 'DiscontinuedReasonID', 'DiscontinuedReason', 'DiscontinuedDate', 'DiscontinuedBy', 'RowVersionID', 'RejectReasonID', 'CreatedDate', 'ModifiedDate', 'StartDateTimeZoneOffset', 'StartDateTimeZone', 'DiscontinuedDateTimeZoneOffset', 'DiscontinuedDateTimeZone', 'PrescriptionGUID', 'ReasonID', 'ReasonText', 'RefillDate', 'RefillReminder', 'DIA', 'DIAOffset', 'DIAValueUpdatedDate', 'Notes'] <--- file_path
# PatientID <--- rawrootid
#
#
# 08_23_2023_ELogFoodItem.csv <--- raw_table_columns
# ['ELogFoodItemID', 'PatientID', 'CarbEntryID', 'FoodName', 'EntrySourceID', 'ActivityTypeID', 'ObservationDateTime', 'ObservationEntryDateTime', 'TimezoneOffset', 'Timezone', 'FoodID', 'ServingSize', 'ServingType', 'Carbs', 'Fiber', 'Fat', 'Calories', 'Protein', 'Sodium', 'ObservationStatus', 'ObservationCreatedBy', 'CreatedDateTime', 'ModifiedDateTime', 'RowVersionID', 'ServingsConsumed', 'ExternalSourceID', 'ExternalEntryID', 'FoodImageID', 'SaturatedFat', 'PolyUnSaturatedFat', 'MonoUnSaturatedFat', 'TransFat', 'Cholesterol', 'Potassium', 'Sugar', 'AddedSugars'] <--- file_path
# PatientID <--- rawrootid
#
#
# 08_23_2023_PatientMeal.csv <--- raw_table_columns
# ['PatientMealID', 'MealID', 'PatientID', 'Name', 'FoodItems', 'StatusID', 'EntryDateTime', 'CreatedDateTime', 'ModifiedDateTime', 'RowVersionID', 'EntrySourceID'] <--- file_path
# PatientID <--- rawrootid
#
#
# 08_23_2023_PatientMeter.csv <--- raw_table_columns
# ['PatientMeterID', 'PatientID', 'MeterName', 'MeterMake', 'MeterModel', 'MeterSerialNumber', 'LastSyncDate', 'MeterStatusID', 'RowVersionID', 'MeterID', 'CreatedDateTime', 'ModifiedDateTime', 'BGIndex', 'Image', 'PeripheralID', 'MeterType'] <--- file_path
# PatientID <--- rawrootid
#
#
# 08_23_2023_BPMeter.csv <--- raw_table_columns
# ['PatientId', 'SerialNumber', 'MeterId', 'Name', 'Make', 'Model', 'LastSyncDateTime', 'StatusId', 'RowVersionId', 'CreatedDateTime', 'ModifiedDateTime', 'Image', 'PeripheralID'] <--- file_path
# PatientId <--- rawrootid
#
#
# 08_23_2023_PatientHeight.csv <--- raw_table_columns
# ['PatientHeightID', 'PatientID', 'ObservationDateTime', 'Height', 'ObservationStatus', 'EntrySourceID', 'OrderEntryID', 'HeighUOMID', 'TimeZoneOffset', 'TimeZone', 'CreatedDateTime', 'ModifiedDateTime', 'RowVersionID'] <--- file_path
# PatientID <--- rawrootid
#
#
# 08_23_2023_CurriculumCourseBadgeDetails.csv <--- raw_table_columns
# ['CourseBadgeID', 'CourseID', 'PatientID', 'RowVersionID', 'CreatedDateTime', 'ModifiedDateTime'] <--- file_path
# PatientID <--- rawrootid
#
#
# 08_23_2023_MedPrescriptionDaySchedule.csv <--- raw_table_columns
# ['MedPrescriptionDayScheduleID', 'MedPrescriptionID', 'AdministrationTimeLabelID', 'FixedDose', 'Carbs', 'CarbsDose', 'BloodGlucoseCorrection', 'BloodGlucoseThreshold', 'BloodGlucoseTarget', 'CorrectionFactorDose', 'RowVersionID', 'PrescriptionGUID', 'MedicationReminder', 'AdministrationTime', 'ScheduledSlot', 'OldAdministrationTime'] <--- file_path
# None <--- rawrootid

# %% [markdown]
# ## [Step 8]: Exclude Raw Table when we select the Patients.
#
#
# We only focus on the patients who have at least one records.
#
# But some table we don't want to consider it. For example, Patient Table.
#
# eg.
#
# patient A: PatientTable 1, ATable 0, BTable 0, CTable 0.
#
# patient B: PatientTable 1, ATable 1, BTable 0, CTable 0
#
#
# We don't want A because A's total record number except PatientTable is 0.
# We want B because B's total  record number except PatientTable is larger than 0.
#
#
# So we put `PatientTable` into `excluded_raw_table_name`.

# %%
# How to get the list. 

# initially, the list is empty
# based on excluded_raw_table_name is empty
# we will get the df_Human (df_Human2RawRecNum) at the end of this notebook.
# Then, we will check the df_Human, and see if there is any table that we want to exclude.
# if there is, we will add the table name to the excluded_raw_table_name list.

#########################
# excluded_raw_table_names = [] 
excluded_raw_table_names = ['UserDetail', 'Patient', 
                           'QuestionResponse', 'PatientBloodGlucoseTargets', 
                           'Rx', 'PatientObservationSummary', 
                           'PatientTargetSegment', 'TDC']
#########################

# %% [markdown]
# ## [Step 9]: Save the above tools into the pipeline folder

# %%
from recfldtkn.loadtools import convert_variables_to_pystirng, load_module_variables

prefix = ['import pandas as pd', 'import numpy as np']
iterative_variables = [selected_source_file_suffix_list, excluded_raw_table_names]
fn_variables = [get_tablename_from_raw_filename, get_rawrootid_from_raw_table_column]
pycode = convert_variables_to_pystirng(iterative_variables = iterative_variables, 
                                       fn_variables = fn_variables, 
                                       prefix = prefix)
pypath = cohort_args['pypath']
# print(pypath)
with open(pypath, 'w') as file: file.write(pycode)
# Create a HTML link and display it
full_path = os.path.join(WORKSPACE_PATH, pypath)
display(HTML(f'{pypath} <a href="{full_path}" target="_blank">Open File</a>'))
# Out:
# [INFO:2024-04-18 23:48:25,040:(config.py@58 datasets)]: PyTorch version 2.1.2+cu121 available.
# ../pipeline/fn_humanrec/humanrec.py <a href="g:\Shared drives\CDHAI-WellDoc\2024-WellDocTest-SPACE\_WellDoc-RFT-WorkSpace\../pipeline/fn_humanrec/humanrec.py" target="_blank">Open File</a>

# %% [markdown]
# # [Part 2] Process dfHumanRec with Pipeline
#
#
# Given ../pipeline/fn_humanrec/humanrec.py  is ready.
#
# We have a pipeline tool: get_cohort_level_record_number_counts
#
# This will call this humanrec.py internally, to process our records.

# %%
cohort_name
# Out:
# 'RawData2023_CVSDeRxAug'

# %%
cohort_label
# Out:
# 3

# %%
cohort_args['pypath']
# Out:
# '../pipeline/fn_humanrec/humanrec.py'

# %% [markdown]
# ## [Step 1]: Call Pipeline to get df_Human
#
# Here we have a pipeline function `get_cohort_level_record_number_counts` to get the df_Human.
#
# It will load the tools from '../pipeline/fn_humanrec/humanrec.py' to do the process.
#
# If you want to know the details of the pipeline_fn, you can go to the unpacking notebook to understand it more.

# %%
from recfldtkn.pipeline_record import get_RawName_to_dfRawPath


OneCohort_Args
# Out:
# {'cohort_label': 3,
#  'cohort_name': 'RawData2023_CVSDeRxAug',
#  'FolderPath': '../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/'}

# %%
rft_config = {
    'base_config': cohort_args, 
}

# %%
RawName_to_dfRawPath = get_RawName_to_dfRawPath(OneCohort_Args, rft_config)
RawName_to_dfRawPath
# Out:
# [INFO:2024-04-18 23:48:25,930:(pipeline_record.py@39 recfldtkn.pipeline_record)]: ../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/ <-- FolderPath
# [INFO:2024-04-18 23:48:25,931:(pipeline_record.py@40 recfldtkn.pipeline_record)]: 41 <--- fullfile_list
# {'MedAdministration': '../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_MedAdministration.csv',
#  'CustomFood': '../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_CustomFood.csv',
#  'RecentElogBGEntry': '../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_RecentElogBGEntry.csv',
#  'ImportedMedication': '../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_ImportedMedication.csv',
#  'ELogCarbsEntry': '../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_ELogCarbsEntry.csv',
#  'CurriculumLessonProgressDetails': '../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_CurriculumLessonProgressDetails.csv',
#  'CurriculumTopicProgressDetails': '../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_CurriculumTopicProgressDetails.csv',
#  'CurriculumQuizResponse': '../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_CurriculumQuizResponse.csv',
#  'SleepEntry': '../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_SleepEntry.csv',
#  'ElogKetoneEntry': '../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_ElogKetoneEntry.csv',
#  'ElogBPEntry': '../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_ElogBPEntry.csv',
#  'PatientReminder': '../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_PatientReminder.csv',
#  'PatientLabTestResult': '../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_PatientLabTestResult.csv',
#  'Patient': '../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_Patient.csv',
#  'PatientTargetSegment': '../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_PatientTargetSegment.csv',
#  'UserDetail': '../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_UserDetail.csv',
#  'PatientBloodGlucoseTargets': '../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_PatientBloodGlucoseTargets.csv',
#  'CurriculumSurveyResponse': '../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_CurriculumSurveyResponse.csv',
#  'ELogSymptomTracker': '../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_ELogSymptomTracker.csv',
#  'FavoriteFood': '../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_FavoriteFood.csv',
#  'StepEntry': '../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_StepEntry.csv',
#  'WeightMeter': '../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_WeightMeter.csv',
#  'WeightGoal': '../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_WeightGoal.csv',
#  'ElogBGEntry': '../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_ElogBGEntry.csv',
#  'ElogWeightEntry': '../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_ElogWeightEntry.csv',
#  'ELogExerciseEntry': '../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_ELogExerciseEntry.csv',
#  'Rx': '../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_31_2023_DSMQuestionAnswer_CVS_Pull_De_Rx.csv',
#  'ELogCommentEntry': '../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_ELogCommentEntry.csv',
#  'CurriculumQuizResult': '../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_CurriculumQuizResult.csv',
#  'PatientLastExam': '../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_PatientLastExam.csv',
#  'PatientCarbTarget': '../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_PatientCarbTarget.csv',
#  'PatientObservationSummary': '../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_PatientObservationSummary.csv',
#  'CurriculumCourseProgressDetails': '../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_CurriculumCourseProgressDetails.csv',
#  'MedPrescription': '../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_MedPrescription.csv',
#  'ELogFoodItem': '../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_ELogFoodItem.csv',
#  'PatientMeal': '../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_PatientMeal.csv',
#  'PatientMeter': '../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_PatientMeter.csv',
#  'BPMeter': '../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_BPMeter.csv',
#  'PatientHeight': '../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_PatientHeight.csv',
#  'CurriculumCourseBadgeDetails': '../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_CurriculumCourseBadgeDetails.csv',
#  'MedPrescriptionDaySchedule': '../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_MedPrescriptionDaySchedule.csv'}

# %%
from recfldtkn.pipeline_record import get_CohortLevel_df_Human2RawRecNum

OneCohort_config = OneCohort_Args
RawName_to_dfRaw = RawName_to_dfRawPath

df_Human = get_CohortLevel_df_Human2RawRecNum(OneCohort_config, 
                                                rft_config, 
                                                RawName_to_dfRaw)


df_Human
# Out:
# [INFO:2024-04-18 23:48:25,971:(pipeline_record.py@91 recfldtkn.pipeline_record)]: =======cohort_label-3: cohort_name-RawData2023_CVSDeRxAug=======
# [INFO:2024-04-18 23:48:25,972:(pipeline_record.py@92 recfldtkn.pipeline_record)]: {'cohort_label': 3, 'cohort_name': 'RawData2023_CVSDeRxAug', 'FolderPath': '../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/'}
# [INFO:2024-04-18 23:48:26,033:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:48:26,035:(pipeline_record.py@166 recfldtkn.pipeline_record)]: MedAdministration:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_MedAdministration.csv' # (36, 3)
# [INFO:2024-04-18 23:48:26,041:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:48:26,042:(pipeline_record.py@166 recfldtkn.pipeline_record)]: CustomFood:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_CustomFood.csv' # (26, 3)
# [INFO:2024-04-18 23:48:26,076:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:48:26,077:(pipeline_record.py@166 recfldtkn.pipeline_record)]: RecentElogBGEntry:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_RecentElogBGEntry.csv' # (33, 3)
# [INFO:2024-04-18 23:48:26,078:(pipeline_record.py@121 recfldtkn.pipeline_record)]: '../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_ImportedMedication.csv' # emtpy file
# [INFO:2024-04-18 23:48:26,117:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:48:26,118:(pipeline_record.py@166 recfldtkn.pipeline_record)]: ELogCarbsEntry:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_ELogCarbsEntry.csv' # (55, 3)
# [INFO:2024-04-18 23:48:26,124:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:48:26,125:(pipeline_record.py@166 recfldtkn.pipeline_record)]: CurriculumLessonProgressDetails:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_CurriculumLessonProgressDetails.csv' # (28, 3)
# [INFO:2024-04-18 23:48:26,146:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:48:26,147:(pipeline_record.py@166 recfldtkn.pipeline_record)]: CurriculumTopicProgressDetails:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_CurriculumTopicProgressDetails.csv' # (28, 3)
# [INFO:2024-04-18 23:48:26,167:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:48:26,168:(pipeline_record.py@166 recfldtkn.pipeline_record)]: CurriculumQuizResponse:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_CurriculumQuizResponse.csv' # (13, 3)
# [INFO:2024-04-18 23:48:26,192:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:48:26,193:(pipeline_record.py@166 recfldtkn.pipeline_record)]: SleepEntry:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_SleepEntry.csv' # (44, 3)
# [INFO:2024-04-18 23:48:26,220:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:48:26,221:(pipeline_record.py@166 recfldtkn.pipeline_record)]: ElogKetoneEntry:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_ElogKetoneEntry.csv' # (51, 3)
# [INFO:2024-04-18 23:48:26,241:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:48:26,243:(pipeline_record.py@166 recfldtkn.pipeline_record)]: ElogBPEntry:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_ElogBPEntry.csv' # (57, 3)
# [INFO:2024-04-18 23:48:26,249:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:48:26,250:(pipeline_record.py@166 recfldtkn.pipeline_record)]: PatientReminder:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_PatientReminder.csv' # (24, 3)
# [INFO:2024-04-18 23:48:26,261:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:48:26,263:(pipeline_record.py@166 recfldtkn.pipeline_record)]: PatientLabTestResult:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_PatientLabTestResult.csv' # (10, 3)
# [INFO:2024-04-18 23:48:26,279:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:48:26,280:(pipeline_record.py@166 recfldtkn.pipeline_record)]: Patient:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_Patient.csv' # (73, 3)
# [INFO:2024-04-18 23:48:26,293:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:48:26,294:(pipeline_record.py@166 recfldtkn.pipeline_record)]: PatientTargetSegment:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_PatientTargetSegment.csv' # (73, 3)
# [INFO:2024-04-18 23:48:26,300:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: UserID
# [INFO:2024-04-18 23:48:26,301:(pipeline_record.py@166 recfldtkn.pipeline_record)]: UserDetail:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_UserDetail.csv' # (84, 3)
# [INFO:2024-04-18 23:48:26,304:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:48:26,305:(pipeline_record.py@166 recfldtkn.pipeline_record)]: PatientBloodGlucoseTargets:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_PatientBloodGlucoseTargets.csv' # (73, 3)
# [INFO:2024-04-18 23:48:26,309:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:48:26,310:(pipeline_record.py@166 recfldtkn.pipeline_record)]: CurriculumSurveyResponse:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_CurriculumSurveyResponse.csv' # (14, 3)
# [INFO:2024-04-18 23:48:26,312:(pipeline_record.py@121 recfldtkn.pipeline_record)]: '../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_ELogSymptomTracker.csv' # emtpy file
# [INFO:2024-04-18 23:48:26,315:(pipeline_record.py@121 recfldtkn.pipeline_record)]: '../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_FavoriteFood.csv' # emtpy file
# [INFO:2024-04-18 23:48:26,349:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:48:26,351:(pipeline_record.py@166 recfldtkn.pipeline_record)]: StepEntry:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_StepEntry.csv' # (31, 3)
# [INFO:2024-04-18 23:48:26,352:(pipeline_record.py@121 recfldtkn.pipeline_record)]: '../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_WeightMeter.csv' # emtpy file
# [INFO:2024-04-18 23:48:26,356:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:48:26,357:(pipeline_record.py@166 recfldtkn.pipeline_record)]: WeightGoal:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_WeightGoal.csv' # (25, 3)
# g:\Shared drives\CDHAI-WellDoc\2024-WellDocTest-SPACE\_WellDoc-RFT-WorkSpace\../pipeline\recfldtkn\pipeline_record.py:128: DtypeWarning: Columns (6,11,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfRaw = pd.read_csv(file_path)
# [INFO:2024-04-18 23:48:27,141:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:48:27,144:(pipeline_record.py@166 recfldtkn.pipeline_record)]: ElogBGEntry:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_ElogBGEntry.csv' # (68, 3)
# [INFO:2024-04-18 23:48:27,244:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: UserID
# [INFO:2024-04-18 23:48:27,245:(pipeline_record.py@166 recfldtkn.pipeline_record)]: ElogWeightEntry:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_ElogWeightEntry.csv' # (66, 3)
# [INFO:2024-04-18 23:48:27,290:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:48:27,292:(pipeline_record.py@166 recfldtkn.pipeline_record)]: ELogExerciseEntry:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_ELogExerciseEntry.csv' # (48, 3)
# [INFO:2024-04-18 23:48:27,332:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: UserID
# [INFO:2024-04-18 23:48:27,333:(pipeline_record.py@166 recfldtkn.pipeline_record)]: Rx:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_31_2023_DSMQuestionAnswer_CVS_Pull_De_Rx.csv' # (73, 3)
# [INFO:2024-04-18 23:48:27,358:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:48:27,359:(pipeline_record.py@166 recfldtkn.pipeline_record)]: ELogCommentEntry:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_ELogCommentEntry.csv' # (56, 3)
# [INFO:2024-04-18 23:48:27,376:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:48:27,377:(pipeline_record.py@166 recfldtkn.pipeline_record)]: CurriculumQuizResult:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_CurriculumQuizResult.csv' # (13, 3)
# [INFO:2024-04-18 23:48:27,381:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:48:27,382:(pipeline_record.py@166 recfldtkn.pipeline_record)]: PatientLastExam:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_PatientLastExam.csv' # (3, 3)
# [INFO:2024-04-18 23:48:27,386:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:48:27,387:(pipeline_record.py@166 recfldtkn.pipeline_record)]: PatientCarbTarget:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_PatientCarbTarget.csv' # (13, 3)
# [INFO:2024-04-18 23:48:27,400:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:48:27,401:(pipeline_record.py@166 recfldtkn.pipeline_record)]: PatientObservationSummary:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_PatientObservationSummary.csv' # (73, 3)
# [INFO:2024-04-18 23:48:27,425:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:48:27,426:(pipeline_record.py@166 recfldtkn.pipeline_record)]: CurriculumCourseProgressDetails:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_CurriculumCourseProgressDetails.csv' # (28, 3)
# [INFO:2024-04-18 23:48:27,452:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:48:27,453:(pipeline_record.py@166 recfldtkn.pipeline_record)]: MedPrescription:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_MedPrescription.csv' # (41, 3)
# [INFO:2024-04-18 23:48:27,631:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:48:27,632:(pipeline_record.py@166 recfldtkn.pipeline_record)]: ELogFoodItem:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_ELogFoodItem.csv' # (55, 3)
# [INFO:2024-04-18 23:48:27,650:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:48:27,651:(pipeline_record.py@166 recfldtkn.pipeline_record)]: PatientMeal:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_PatientMeal.csv' # (19, 3)
# [INFO:2024-04-18 23:48:27,665:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:48:27,666:(pipeline_record.py@166 recfldtkn.pipeline_record)]: PatientMeter:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_PatientMeter.csv' # (63, 3)
# [INFO:2024-04-18 23:48:27,694:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientId
# [INFO:2024-04-18 23:48:27,696:(pipeline_record.py@166 recfldtkn.pipeline_record)]: BPMeter:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_BPMeter.csv' # (41, 3)
# [INFO:2024-04-18 23:48:27,701:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:48:27,702:(pipeline_record.py@166 recfldtkn.pipeline_record)]: PatientHeight:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_PatientHeight.csv' # (32, 3)
# [INFO:2024-04-18 23:48:27,706:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:48:27,707:(pipeline_record.py@166 recfldtkn.pipeline_record)]: CurriculumCourseBadgeDetails:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_CurriculumCourseBadgeDetails.csv' # (15, 3)
# [INFO:2024-04-18 23:48:27,720:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: None
# [INFO:2024-04-18 23:48:27,721:(pipeline_record.py@166 recfldtkn.pipeline_record)]: MedPrescriptionDaySchedule:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_MedPrescriptionDaySchedule.csv' # (0, 3)
# [INFO:2024-04-18 23:48:27,722:(pipeline_record.py@169 recfldtkn.pipeline_record)]: 37 <---- types of dfRec so far
# [INFO:2024-04-18 23:48:27,728:(pipeline_record.py@182 recfldtkn.pipeline_record)]: The patient cohort size: 69
# RawName      PID  PatientID  BPMeter  CurriculumCourseBadgeDetails  \
# 0        3000001       2572      NaN                           NaN
# 1        3000002       2624      NaN                           NaN
# 2        3000003       2636      NaN                           NaN
# 3        3000004       2689      3.0                           2.0
# 4        3000005       2715      1.0                           2.0
# ..           ...        ...      ...                           ...
# 64       3000065       3549      2.0                           2.0
# 65       3000066       3552      2.0                           NaN
# 66       3000067       3625      NaN                           NaN
# 67       3000068       3686      1.0                           NaN
# 68       3000069       4113      2.0                           5.0
#
# RawName  CurriculumCourseProgressDetails  CurriculumLessonProgressDetails  \
# 0                                    NaN                              NaN
# 1                                    1.0                              1.0
# 2                                    NaN                              NaN
# 3                                   11.0                             52.0
# 4                                   11.0                             52.0
# ..                                   ...                              ...
# 64                                  11.0                             55.0
# 65                                   NaN                              NaN
# 66                                   NaN                              NaN
# 67                                   NaN                              NaN
# 68                                  11.0                             55.0
#
# RawName  CurriculumQuizResponse  CurriculumQuizResult  \
# 0                           NaN                   NaN
# 1                           NaN                   NaN
# 2                           NaN                   NaN
# 3                           1.0                   1.0
# 4                           2.0                   2.0
# ..                          ...                   ...
# 64                          1.0                   1.0
# 65                          NaN                   NaN
# 66                          NaN                   NaN
# 67                          NaN                   NaN
# 68                         61.0                   6.0
#
# RawName  CurriculumSurveyResponse  CurriculumTopicProgressDetails  ...  \
# 0                             NaN                             NaN  ...
# 1                             NaN                             1.0  ...
# 2                             NaN                             NaN  ...
# 3                            32.0                             1.0  ...
# 4                            32.0                             1.0  ...
# ..                            ...                             ...  ...
# 64                           30.0                             1.0  ...
# 65                            NaN                             NaN  ...
# 66                            NaN                             NaN  ...
# 67                            NaN                             NaN  ...
# 68                           36.0                             1.0  ...
#
# RawName  PatientReminder  PatientTargetSegment  RecentElogBGEntry    Rx  \
# 0                    NaN                   1.0                NaN   5.0
# 1                    NaN                   1.0                NaN   5.0
# 2                   21.0                   1.0                NaN   5.0
# 3                    6.0                   1.0            10392.0  14.0
# 4                   18.0                   1.0               38.0  14.0
# ..                   ...                   ...                ...   ...
# 64                   1.0                   1.0                NaN   5.0
# 65                   7.0                   1.0                3.0  15.0
# 66                   NaN                   1.0                NaN   5.0
# 67                   NaN                   1.0                NaN   5.0
# 68                   NaN                   1.0                NaN  14.0
#
# RawName  SleepEntry  StepEntry  UserDetail  WeightGoal  TotalRecNum  \
# 0               NaN        NaN         1.0         NaN            2
# 1             109.0        NaN         1.0         NaN          708
# 2               NaN        NaN         1.0         1.0          895
# 3               2.0        NaN         1.0         2.0       127301
# 4             425.0        NaN         1.0         2.0        10496
# ..              ...        ...         ...         ...          ...
# 64           1174.0      187.0         1.0         NaN         5120
# 65             38.0      170.0         1.0         4.0         2590
# 66              NaN        NaN         1.0         NaN           52
# 67              NaN        NaN         1.0         NaN           31
# 68             84.0      241.0         1.0         NaN         1964
#
# RawName  CohortLabel
# 0                  3
# 1                  3
# 2                  3
# 3                  3
# 4                  3
# ..               ...
# 64                 3
# 65                 3
# 66                 3
# 67                 3
# 68                 3
#
# [69 rows x 40 columns]

# %%
[i for i in RawName_to_dfRawPath]
# Out:
# ['MedAdministration',
#  'CustomFood',
#  'RecentElogBGEntry',
#  'ImportedMedication',
#  'ELogCarbsEntry',
#  'CurriculumLessonProgressDetails',
#  'CurriculumTopicProgressDetails',
#  'CurriculumQuizResponse',
#  'SleepEntry',
#  'ElogKetoneEntry',
#  'ElogBPEntry',
#  'PatientReminder',
#  'PatientLabTestResult',
#  'Patient',
#  'PatientTargetSegment',
#  'UserDetail',
#  'PatientBloodGlucoseTargets',
#  'CurriculumSurveyResponse',
#  'ELogSymptomTracker',
#  'FavoriteFood',
#  'StepEntry',
#  'WeightMeter',
#  'WeightGoal',
#  'ElogBGEntry',
#  'ElogWeightEntry',
#  'ELogExerciseEntry',
#  'Rx',
#  'ELogCommentEntry',
#  'CurriculumQuizResult',
#  'PatientLastExam',
#  'PatientCarbTarget',
#  'PatientObservationSummary',
#  'CurriculumCourseProgressDetails',
#  'MedPrescription',
#  'ELogFoodItem',
#  'PatientMeal',
#  'PatientMeter',
#  'BPMeter',
#  'PatientHeight',
#  'CurriculumCourseBadgeDetails',
#  'MedPrescriptionDaySchedule']

# %%
columns = [i for i in RawName_to_dfRawPath if i in df_Human.columns] 
df_Human[columns] = df_Human[columns].astype(float)

# %% [markdown]
# # [Step 2] Check and Update excluded_raw_table_names

# %%
df_Human
# Out:
# RawName      PID  PatientID  BPMeter  CurriculumCourseBadgeDetails  \
# 0        3000001       2572      NaN                           NaN
# 1        3000002       2624      NaN                           NaN
# 2        3000003       2636      NaN                           NaN
# 3        3000004       2689      3.0                           2.0
# 4        3000005       2715      1.0                           2.0
# ..           ...        ...      ...                           ...
# 64       3000065       3549      2.0                           2.0
# 65       3000066       3552      2.0                           NaN
# 66       3000067       3625      NaN                           NaN
# 67       3000068       3686      1.0                           NaN
# 68       3000069       4113      2.0                           5.0
#
# RawName  CurriculumCourseProgressDetails  CurriculumLessonProgressDetails  \
# 0                                    NaN                              NaN
# 1                                    1.0                              1.0
# 2                                    NaN                              NaN
# 3                                   11.0                             52.0
# 4                                   11.0                             52.0
# ..                                   ...                              ...
# 64                                  11.0                             55.0
# 65                                   NaN                              NaN
# 66                                   NaN                              NaN
# 67                                   NaN                              NaN
# 68                                  11.0                             55.0
#
# RawName  CurriculumQuizResponse  CurriculumQuizResult  \
# 0                           NaN                   NaN
# 1                           NaN                   NaN
# 2                           NaN                   NaN
# 3                           1.0                   1.0
# 4                           2.0                   2.0
# ..                          ...                   ...
# 64                          1.0                   1.0
# 65                          NaN                   NaN
# 66                          NaN                   NaN
# 67                          NaN                   NaN
# 68                         61.0                   6.0
#
# RawName  CurriculumSurveyResponse  CurriculumTopicProgressDetails  ...  \
# 0                             NaN                             NaN  ...
# 1                             NaN                             1.0  ...
# 2                             NaN                             NaN  ...
# 3                            32.0                             1.0  ...
# 4                            32.0                             1.0  ...
# ..                            ...                             ...  ...
# 64                           30.0                             1.0  ...
# 65                            NaN                             NaN  ...
# 66                            NaN                             NaN  ...
# 67                            NaN                             NaN  ...
# 68                           36.0                             1.0  ...
#
# RawName  PatientReminder  PatientTargetSegment  RecentElogBGEntry    Rx  \
# 0                    NaN                   1.0                NaN   5.0
# 1                    NaN                   1.0                NaN   5.0
# 2                   21.0                   1.0                NaN   5.0
# 3                    6.0                   1.0            10392.0  14.0
# 4                   18.0                   1.0               38.0  14.0
# ..                   ...                   ...                ...   ...
# 64                   1.0                   1.0                NaN   5.0
# 65                   7.0                   1.0                3.0  15.0
# 66                   NaN                   1.0                NaN   5.0
# 67                   NaN                   1.0                NaN   5.0
# 68                   NaN                   1.0                NaN  14.0
#
# RawName  SleepEntry  StepEntry  UserDetail  WeightGoal  TotalRecNum  \
# 0               NaN        NaN         1.0         NaN            2
# 1             109.0        NaN         1.0         NaN          708
# 2               NaN        NaN         1.0         1.0          895
# 3               2.0        NaN         1.0         2.0       127301
# 4             425.0        NaN         1.0         2.0        10496
# ..              ...        ...         ...         ...          ...
# 64           1174.0      187.0         1.0         NaN         5120
# 65             38.0      170.0         1.0         4.0         2590
# 66              NaN        NaN         1.0         NaN           52
# 67              NaN        NaN         1.0         NaN           31
# 68             84.0      241.0         1.0         NaN         1964
#
# RawName  CohortLabel
# 0                  3
# 1                  3
# 2                  3
# 3                  3
# 4                  3
# ..               ...
# 64                 3
# 65                 3
# 66                 3
# 67                 3
# 68                 3
#
# [69 rows x 40 columns]

# %% [markdown]
# # [Step 3] Save ds_Human as HFDS

# %%
import datasets
ds_HumanRec = datasets.Dataset.from_pandas(df_Human)
print(ds_HumanRec)
# Out:
# Dataset({
#     features: ['PID', 'PatientID', 'BPMeter', 'CurriculumCourseBadgeDetails', 'CurriculumCourseProgressDetails', 'CurriculumLessonProgressDetails', 'CurriculumQuizResponse', 'CurriculumQuizResult', 'CurriculumSurveyResponse', 'CurriculumTopicProgressDetails', 'CustomFood', 'ELogCarbsEntry', 'ELogCommentEntry', 'ELogExerciseEntry', 'ELogFoodItem', 'ElogBGEntry', 'ElogBPEntry', 'ElogKetoneEntry', 'ElogWeightEntry', 'MedAdministration', 'MedPrescription', 'Patient', 'PatientBloodGlucoseTargets', 'PatientCarbTarget', 'PatientHeight', 'PatientLabTestResult', 'PatientLastExam', 'PatientMeal', 'PatientMeter', 'PatientObservationSummary', 'PatientReminder', 'PatientTargetSegment', 'RecentElogBGEntry', 'Rx', 'SleepEntry', 'StepEntry', 'UserDetail', 'WeightGoal', 'TotalRecNum', 'CohortLabel'],
#     num_rows: 69
# })

# %%
cohort_args['RecName']
# Out:
# 'PRawRecNum'

# %%
print(SPACE['DATA_RFT'])

full_cohort_name = f'{cohort_label}-{cohort_name}'
print(full_cohort_name)
# ------------------------------------------------------------------------- # 
path = os.path.join(SPACE['DATA_RFT'], full_cohort_name, cohort_args['RecName'] + '_data')
print(path)
ds_HumanRec.save_to_disk(path)
print(ds_HumanRec)
# Out:
# ../_Data/1-Data_RFT
# 3-RawData2023_CVSDeRxAug
# ../_Data/1-Data_RFT\3-RawData2023_CVSDeRxAug\PRawRecNum_data
# Saving the dataset (0/1 shards):   0%|          | 0/69 [00:00<?, ? examples/s]
# Dataset({
#     features: ['PID', 'PatientID', 'BPMeter', 'CurriculumCourseBadgeDetails', 'CurriculumCourseProgressDetails', 'CurriculumLessonProgressDetails', 'CurriculumQuizResponse', 'CurriculumQuizResult', 'CurriculumSurveyResponse', 'CurriculumTopicProgressDetails', 'CustomFood', 'ELogCarbsEntry', 'ELogCommentEntry', 'ELogExerciseEntry', 'ELogFoodItem', 'ElogBGEntry', 'ElogBPEntry', 'ElogKetoneEntry', 'ElogWeightEntry', 'MedAdministration', 'MedPrescription', 'Patient', 'PatientBloodGlucoseTargets', 'PatientCarbTarget', 'PatientHeight', 'PatientLabTestResult', 'PatientLastExam', 'PatientMeal', 'PatientMeter', 'PatientObservationSummary', 'PatientReminder', 'PatientTargetSegment', 'RecentElogBGEntry', 'Rx', 'SleepEntry', 'StepEntry', 'UserDetail', 'WeightGoal', 'TotalRecNum', 'CohortLabel'],
#     num_rows: 69
# })

# %%
import shutil
from recfldtkn.pipeline_record import pipeline_for_FldTkn
import shutil
from recfldtkn.pipeline_record import pipeline_for_FldTkn
from recfldtkn.configfn import load_cohort_args
from recfldtkn.configfn import load_record_args
from recfldtkn.pipeline_record import pipeline_record
from recfldtkn.configfn import load_rft_config
from recfldtkn.loadtools import filter_with_cohort_label, load_ds_rec_and_info
from recfldtkn.pipeline_record import get_parentRecord_info

cohort_args = load_cohort_args(recfldtkn_config_path, SPACE)


############################
cohort_label_list = [1, 2, 3]
############################
cohort_label_to_cohort_name = {str(v['cohort_label']): k for k, v in cohort_args['CohortInfo'].items()}

for cohort_label in cohort_label_list:
    
    cohort_name = cohort_label_to_cohort_name[str(cohort_label)]
    OneCohort_config = cohort_args['CohortInfo'][cohort_name]
    
    logger.info(f'==================== {cohort_name}: {cohort_label} =====================')
    logger.info(OneCohort_config)
    
    
    cohort_label = OneCohort_config['cohort_label']
    cohort_name = OneCohort_config['cohort_name']
    # base_config = rft_config['base_config'] 
    SPACE = cohort_args['SPACE']

    # Step 1: df_Human
    path_dfHuman = os.path.join(SPACE['DATA_RFT'], 
                                f'{cohort_label}-{cohort_name}', 
                                cohort_args['RecName'] + '_data')
    
    
    rft_config = {
        'base_config': cohort_args, 
    }

    RawName_to_dfRawPath = get_RawName_to_dfRawPath(OneCohort_config, rft_config)
    RawName_to_dfRaw = RawName_to_dfRawPath



    df_Human = get_CohortLevel_df_Human2RawRecNum(OneCohort_config, 
                                                    rft_config, 
                                                    RawName_to_dfRaw)
    
    print(df_Human.shape)
    logger.info(f'Save df_Human to: {path_dfHuman}')
    
    ds_HumanRec = datasets.Dataset.from_pandas(df_Human)
    ds_HumanRec.save_to_disk(path_dfHuman)
# Out:
# [INFO:2024-04-18 23:50:45,685:(976063671.py@25 __main__)]: ==================== RawData2022_CGM: 1 =====================
# [INFO:2024-04-18 23:50:45,685:(976063671.py@26 __main__)]: {'cohort_label': 1, 'cohort_name': 'RawData2022_CGM', 'FolderPath': '../_Data/0-Data_Raw/RawData2022_CGM/'}
# [INFO:2024-04-18 23:50:45,687:(pipeline_record.py@39 recfldtkn.pipeline_record)]: ../_Data/0-Data_Raw/RawData2022_CGM/ <-- FolderPath
# [INFO:2024-04-18 23:50:45,688:(pipeline_record.py@40 recfldtkn.pipeline_record)]: 32 <--- fullfile_list
# [INFO:2024-04-18 23:50:45,688:(pipeline_record.py@91 recfldtkn.pipeline_record)]: =======cohort_label-1: cohort_name-RawData2022_CGM=======
# [INFO:2024-04-18 23:50:45,688:(pipeline_record.py@92 recfldtkn.pipeline_record)]: {'cohort_label': 1, 'cohort_name': 'RawData2022_CGM', 'FolderPath': '../_Data/0-Data_Raw/RawData2022_CGM/'}
# [INFO:2024-04-18 23:50:45,690:(pipeline_record.py@131 recfldtkn.pipeline_record)]: '../_Data/0-Data_Raw/RawData2022_CGM/05_02_2022_ElogBGEntry.csv' # larger than 1GB
# [INFO:2024-04-18 23:50:45,690:(pipeline_record.py@158 recfldtkn.pipeline_record)]: processing large file: '../_Data/0-Data_Raw/RawData2022_CGM/05_02_2022_ElogBGEntry.csv'
# [INFO:2024-04-18 23:50:45,709:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:19,652:(pipeline_record.py@166 recfldtkn.pipeline_record)]: ElogBGEntry:'path-../_Data/0-Data_Raw/RawData2022_CGM/05_02_2022_ElogBGEntry.csv' # (1293, 3)
# [INFO:2024-04-18 23:51:19,720:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:19,723:(pipeline_record.py@166 recfldtkn.pipeline_record)]: ElogBPEntry:'path-../_Data/0-Data_Raw/RawData2022_CGM/05_02_2022_ElogBPEntry.csv' # (558, 3)
# [INFO:2024-04-18 23:51:19,745:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientId
# [INFO:2024-04-18 23:51:19,746:(pipeline_record.py@166 recfldtkn.pipeline_record)]: WeightMeter:'path-../_Data/0-Data_Raw/RawData2022_CGM/05_12_2022_WeightMeter.csv' # (2, 3)
# [INFO:2024-04-18 23:51:19,783:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:19,785:(pipeline_record.py@166 recfldtkn.pipeline_record)]: PatientLastExam:'path-../_Data/0-Data_Raw/RawData2022_CGM/05_02_2022_PatientLastExam.csv' # (148, 3)
# [INFO:2024-04-18 23:51:19,883:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:19,885:(pipeline_record.py@166 recfldtkn.pipeline_record)]: PatientWeeklyChallenge:'path-../_Data/0-Data_Raw/RawData2022_CGM/05_02_2022_PatientWeeklyChallenge.csv' # (2567, 3)
# [INFO:2024-04-18 23:51:19,904:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:19,906:(pipeline_record.py@166 recfldtkn.pipeline_record)]: WeightGoal:'path-../_Data/0-Data_Raw/RawData2022_CGM/05_02_2022_WeightGoal.csv' # (411, 3)
# [INFO:2024-04-18 23:51:19,960:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:19,962:(pipeline_record.py@166 recfldtkn.pipeline_record)]: LearningLibraryLikeFavorite:'path-../_Data/0-Data_Raw/RawData2022_CGM/05_12_2022_LearningLibraryLikeFavorite.csv' # (3705, 3)
# [INFO:2024-04-18 23:51:20,163:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:20,166:(pipeline_record.py@166 recfldtkn.pipeline_record)]: SleepEntry:'path-../_Data/0-Data_Raw/RawData2022_CGM/05_02_2022_SleepEntry.csv' # (627, 3)
# [INFO:2024-04-18 23:51:20,285:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:20,288:(pipeline_record.py@166 recfldtkn.pipeline_record)]: QuestionResponse:'path-../_Data/0-Data_Raw/RawData2022_CGM/05_12_2022_QuestionResponse.csv' # (14932, 3)
# [INFO:2024-04-18 23:51:20,313:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:20,315:(pipeline_record.py@166 recfldtkn.pipeline_record)]: CustomFood:'path-../_Data/0-Data_Raw/RawData2022_CGM/05_02_2022_CustomFood.csv' # (98, 3)
# [INFO:2024-04-18 23:51:20,354:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:20,356:(pipeline_record.py@166 recfldtkn.pipeline_record)]: PatientBloodGlucoseTargets:'path-../_Data/0-Data_Raw/RawData2022_CGM/05_02_2022_PatientBloodGlucoseTargets.csv' # (14615, 3)
# [INFO:2024-04-18 23:51:20,386:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:20,388:(pipeline_record.py@166 recfldtkn.pipeline_record)]: ELogCommentEntry:'path-../_Data/0-Data_Raw/RawData2022_CGM/05_02_2022_ELogCommentEntry.csv' # (510, 3)
# [INFO:2024-04-18 23:51:20,418:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:20,419:(pipeline_record.py@166 recfldtkn.pipeline_record)]: ImportedMedication:'path-../_Data/0-Data_Raw/RawData2022_CGM/05_02_2022_ImportedMedication.csv' # (105, 3)
# [INFO:2024-04-18 23:51:20,751:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:20,753:(pipeline_record.py@166 recfldtkn.pipeline_record)]: MedAdministration:'path-../_Data/0-Data_Raw/RawData2022_CGM/05_02_2022_MedAdministration.csv' # (740, 3)
# [INFO:2024-04-18 23:51:20,869:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:20,871:(pipeline_record.py@166 recfldtkn.pipeline_record)]: ELogCarbsEntry:'path-../_Data/0-Data_Raw/RawData2022_CGM/05_02_2022_ELogCarbsEntry.csv' # (686, 3)
# [INFO:2024-04-18 23:51:20,984:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:20,986:(pipeline_record.py@166 recfldtkn.pipeline_record)]: ElogWeightEntry:'path-../_Data/0-Data_Raw/RawData2022_CGM/05_02_2022_ElogWeightEntry.csv' # (1204, 3)
# [INFO:2024-04-18 23:51:21,006:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientId
# [INFO:2024-04-18 23:51:21,008:(pipeline_record.py@166 recfldtkn.pipeline_record)]: BPMeter:'path-../_Data/0-Data_Raw/RawData2022_CGM/05_12_2022_BPMeter.csv' # (17, 3)
# [INFO:2024-04-18 23:51:21,059:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:21,061:(pipeline_record.py@166 recfldtkn.pipeline_record)]: PatientLabTestResult:'path-../_Data/0-Data_Raw/RawData2022_CGM/05_02_2022_PatientLabTestResult.csv' # (691, 3)
# [INFO:2024-04-18 23:51:21,165:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:21,167:(pipeline_record.py@166 recfldtkn.pipeline_record)]: StepEntry:'path-../_Data/0-Data_Raw/RawData2022_CGM/05_02_2022_StepEntry.csv' # (351, 3)
# [INFO:2024-04-18 23:51:21,380:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: UserID
# [INFO:2024-04-18 23:51:21,382:(pipeline_record.py@166 recfldtkn.pipeline_record)]: UserDetail:'path-../_Data/0-Data_Raw/RawData2022_CGM/05_02_2022_UserDetail.csv' # (14716, 3)
# g:\Shared drives\CDHAI-WellDoc\2024-WellDocTest-SPACE\_WellDoc-RFT-WorkSpace\../pipeline\recfldtkn\pipeline_record.py:128: DtypeWarning: Columns (72) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfRaw = pd.read_csv(file_path)
# [INFO:2024-04-18 23:51:21,525:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:21,527:(pipeline_record.py@166 recfldtkn.pipeline_record)]: Patient:'path-../_Data/0-Data_Raw/RawData2022_CGM/05_02_2022_Patient.csv' # (14692, 3)
# [INFO:2024-04-18 23:51:21,556:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:21,557:(pipeline_record.py@166 recfldtkn.pipeline_record)]: PatientCarbTarget:'path-../_Data/0-Data_Raw/RawData2022_CGM/05_02_2022_PatientCarbTarget.csv' # (301, 3)
# [INFO:2024-04-18 23:51:21,602:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:21,604:(pipeline_record.py@166 recfldtkn.pipeline_record)]: MedPrescription:'path-../_Data/0-Data_Raw/RawData2022_CGM/05_02_2022_MedPrescription.csv' # (2184, 3)
# [INFO:2024-04-18 23:51:21,626:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: UserID
# [INFO:2024-04-18 23:51:21,628:(pipeline_record.py@166 recfldtkn.pipeline_record)]: ActivityTracker:'path-../_Data/0-Data_Raw/RawData2022_CGM/05_12_2022_ActivityTracker.csv' # (581, 3)
# [INFO:2024-04-18 23:51:21,654:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:21,656:(pipeline_record.py@166 recfldtkn.pipeline_record)]: PatientCGMDeviceDetail:'path-../_Data/0-Data_Raw/RawData2022_CGM/05_12_2022_PatientCGMDeviceDetail.csv' # (723, 3)
# [INFO:2024-04-18 23:51:21,797:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:21,799:(pipeline_record.py@166 recfldtkn.pipeline_record)]: ELogFoodItem:'path-../_Data/0-Data_Raw/RawData2022_CGM/05_02_2022_ELogFoodItem.csv' # (686, 3)
# [INFO:2024-04-18 23:51:21,942:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:21,944:(pipeline_record.py@166 recfldtkn.pipeline_record)]: ELogExerciseEntry:'path-../_Data/0-Data_Raw/RawData2022_CGM/05_02_2022_ELogExerciseEntry.csv' # (446, 3)
# [INFO:2024-04-18 23:51:21,968:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:21,970:(pipeline_record.py@166 recfldtkn.pipeline_record)]: PatientHeight:'path-../_Data/0-Data_Raw/RawData2022_CGM/05_02_2022_PatientHeight.csv' # (655, 3)
# [INFO:2024-04-18 23:51:21,990:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:21,992:(pipeline_record.py@166 recfldtkn.pipeline_record)]: CGMConnection:'path-../_Data/0-Data_Raw/RawData2022_CGM/05_12_2022_CGMConnection.csv' # (723, 3)
# [INFO:2024-04-18 23:51:22,022:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:22,024:(pipeline_record.py@166 recfldtkn.pipeline_record)]: PatientMeal:'path-../_Data/0-Data_Raw/RawData2022_CGM/05_02_2022_PatientMeal.csv' # (60, 3)
# [INFO:2024-04-18 23:51:22,047:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:22,048:(pipeline_record.py@166 recfldtkn.pipeline_record)]: PatientCurriculumCourseProgress:'path-../_Data/0-Data_Raw/RawData2022_CGM/12_14_2022_PatientCurriculumCourseProgress.csv' # (708, 3)
# [INFO:2024-04-18 23:51:22,067:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:22,068:(pipeline_record.py@166 recfldtkn.pipeline_record)]: PatientMeter:'path-../_Data/0-Data_Raw/RawData2022_CGM/05_12_2022_PatientMeter.csv' # (90, 3)
# [INFO:2024-04-18 23:51:22,069:(pipeline_record.py@169 recfldtkn.pipeline_record)]: 32 <---- types of dfRec so far
# [INFO:2024-04-18 23:51:22,098:(pipeline_record.py@182 recfldtkn.pipeline_record)]: The patient cohort size: 7379
# [INFO:2024-04-18 23:51:22,107:(976063671.py@54 __main__)]: Save df_Human to: ../_Data/1-Data_RFT\1-RawData2022_CGM\PRawRecNum_data
# (7379, 36)
# Saving the dataset (0/1 shards):   0%|          | 0/7379 [00:00<?, ? examples/s]
# [INFO:2024-04-18 23:51:22,248:(976063671.py@25 __main__)]: ==================== RawData2023_CVSTDCAug: 2 =====================
# [INFO:2024-04-18 23:51:22,249:(976063671.py@26 __main__)]: {'cohort_label': 2, 'cohort_name': 'RawData2023_CVSTDCAug', 'FolderPath': '../_Data/0-Data_Raw/RawData2023_CVSTDCAug/'}
# [INFO:2024-04-18 23:51:22,252:(pipeline_record.py@39 recfldtkn.pipeline_record)]: ../_Data/0-Data_Raw/RawData2023_CVSTDCAug/ <-- FolderPath
# [INFO:2024-04-18 23:51:22,253:(pipeline_record.py@40 recfldtkn.pipeline_record)]: 41 <--- fullfile_list
# [INFO:2024-04-18 23:51:22,253:(pipeline_record.py@91 recfldtkn.pipeline_record)]: =======cohort_label-2: cohort_name-RawData2023_CVSTDCAug=======
# [INFO:2024-04-18 23:51:22,253:(pipeline_record.py@92 recfldtkn.pipeline_record)]: {'cohort_label': 2, 'cohort_name': 'RawData2023_CVSTDCAug', 'FolderPath': '../_Data/0-Data_Raw/RawData2023_CVSTDCAug/'}
# [INFO:2024-04-18 23:51:22,333:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:22,335:(pipeline_record.py@166 recfldtkn.pipeline_record)]: ElogBPEntry:'path-../_Data/0-Data_Raw/RawData2023_CVSTDCAug/08_23_2023_ElogBPEntry.csv' # (712, 3)
# [INFO:2024-04-18 23:51:22,337:(pipeline_record.py@121 recfldtkn.pipeline_record)]: '../_Data/0-Data_Raw/RawData2023_CVSTDCAug/08_23_2023_ELogSymptomTracker.csv' # emtpy file
# [INFO:2024-04-18 23:51:22,356:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:22,357:(pipeline_record.py@166 recfldtkn.pipeline_record)]: CustomFood:'path-../_Data/0-Data_Raw/RawData2023_CVSTDCAug/08_23_2023_CustomFood.csv' # (109, 3)
# [INFO:2024-04-18 23:51:22,359:(pipeline_record.py@121 recfldtkn.pipeline_record)]: '../_Data/0-Data_Raw/RawData2023_CVSTDCAug/08_23_2023_FavoriteFood.csv' # emtpy file
# [INFO:2024-04-18 23:51:22,397:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:22,399:(pipeline_record.py@166 recfldtkn.pipeline_record)]: CurriculumTopicProgressDetails:'path-../_Data/0-Data_Raw/RawData2023_CVSTDCAug/08_23_2023_CurriculumTopicProgressDetails.csv' # (1521, 3)
# [INFO:2024-04-18 23:51:22,444:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:22,446:(pipeline_record.py@166 recfldtkn.pipeline_record)]: MedPrescription:'path-../_Data/0-Data_Raw/RawData2023_CVSTDCAug/08_23_2023_MedPrescription.csv' # (1987, 3)
# [INFO:2024-04-18 23:51:22,448:(pipeline_record.py@131 recfldtkn.pipeline_record)]: '../_Data/0-Data_Raw/RawData2023_CVSTDCAug/08_23_2023_ElogBGEntry.csv' # larger than 1GB
# [INFO:2024-04-18 23:51:22,448:(pipeline_record.py@158 recfldtkn.pipeline_record)]: processing large file: '../_Data/0-Data_Raw/RawData2023_CVSTDCAug/08_23_2023_ElogBGEntry.csv'
# [INFO:2024-04-18 23:51:22,465:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:29,315:(pipeline_record.py@166 recfldtkn.pipeline_record)]: ElogBGEntry:'path-../_Data/0-Data_Raw/RawData2023_CVSTDCAug/08_23_2023_ElogBGEntry.csv' # (1907, 3)
# [INFO:2024-04-18 23:51:29,370:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:29,371:(pipeline_record.py@166 recfldtkn.pipeline_record)]: ELogCommentEntry:'path-../_Data/0-Data_Raw/RawData2023_CVSTDCAug/08_23_2023_ELogCommentEntry.csv' # (603, 3)
# [INFO:2024-04-18 23:51:29,401:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:29,404:(pipeline_record.py@166 recfldtkn.pipeline_record)]: PatientMeter:'path-../_Data/0-Data_Raw/RawData2023_CVSTDCAug/08_23_2023_PatientMeter.csv' # (628, 3)
# [INFO:2024-04-18 23:51:29,483:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:29,485:(pipeline_record.py@166 recfldtkn.pipeline_record)]: ELogCarbsEntry:'path-../_Data/0-Data_Raw/RawData2023_CVSTDCAug/08_23_2023_ELogCarbsEntry.csv' # (924, 3)
# [INFO:2024-04-18 23:51:29,487:(pipeline_record.py@121 recfldtkn.pipeline_record)]: '../_Data/0-Data_Raw/RawData2023_CVSTDCAug/08_23_2023_ElogKetoneEntry.csv' # emtpy file
# [INFO:2024-04-18 23:51:29,513:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:29,514:(pipeline_record.py@166 recfldtkn.pipeline_record)]: ImportedMedication:'path-../_Data/0-Data_Raw/RawData2023_CVSTDCAug/08_23_2023_ImportedMedication.csv' # (55, 3)
# g:\Shared drives\CDHAI-WellDoc\2024-WellDocTest-SPACE\_WellDoc-RFT-WorkSpace\../pipeline\recfldtkn\pipeline_record.py:128: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfRaw = pd.read_csv(file_path)
# [INFO:2024-04-18 23:51:30,452:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: UserID
# [INFO:2024-04-18 23:51:30,454:(pipeline_record.py@166 recfldtkn.pipeline_record)]: ElogWeightEntry:'path-../_Data/0-Data_Raw/RawData2023_CVSTDCAug/08_23_2023_ElogWeightEntry.csv' # (1184, 3)
# [INFO:2024-04-18 23:51:30,504:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:30,506:(pipeline_record.py@166 recfldtkn.pipeline_record)]: CurriculumSurveyResponse:'path-../_Data/0-Data_Raw/RawData2023_CVSTDCAug/08_23_2023_CurriculumSurveyResponse.csv' # (779, 3)
# [INFO:2024-04-18 23:51:30,530:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:30,532:(pipeline_record.py@166 recfldtkn.pipeline_record)]: CurriculumCourseProgressDetails:'path-../_Data/0-Data_Raw/RawData2023_CVSTDCAug/08_23_2023_CurriculumCourseProgressDetails.csv' # (1521, 3)
# [INFO:2024-04-18 23:51:30,571:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:30,572:(pipeline_record.py@166 recfldtkn.pipeline_record)]: PatientMeal:'path-../_Data/0-Data_Raw/RawData2023_CVSTDCAug/08_23_2023_PatientMeal.csv' # (89, 3)
# [INFO:2024-04-18 23:51:30,587:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientId
# [INFO:2024-04-18 23:51:30,588:(pipeline_record.py@166 recfldtkn.pipeline_record)]: BPMeter:'path-../_Data/0-Data_Raw/RawData2023_CVSTDCAug/08_23_2023_BPMeter.csv' # (174, 3)
# [INFO:2024-04-18 23:51:30,607:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:30,608:(pipeline_record.py@166 recfldtkn.pipeline_record)]: PatientLastExam:'path-../_Data/0-Data_Raw/RawData2023_CVSTDCAug/08_23_2023_PatientLastExam.csv' # (120, 3)
# [INFO:2024-04-18 23:51:30,654:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:30,656:(pipeline_record.py@166 recfldtkn.pipeline_record)]: PatientBloodGlucoseTargets:'path-../_Data/0-Data_Raw/RawData2023_CVSTDCAug/08_23_2023_PatientBloodGlucoseTargets.csv' # (8303, 3)
# [INFO:2024-04-18 23:51:30,698:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:30,700:(pipeline_record.py@166 recfldtkn.pipeline_record)]: PatientLabTestResult:'path-../_Data/0-Data_Raw/RawData2023_CVSTDCAug/08_23_2023_PatientLabTestResult.csv' # (483, 3)
# [INFO:2024-04-18 23:51:30,749:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:30,751:(pipeline_record.py@166 recfldtkn.pipeline_record)]: CurriculumLessonProgressDetails:'path-../_Data/0-Data_Raw/RawData2023_CVSTDCAug/08_23_2023_CurriculumLessonProgressDetails.csv' # (1521, 3)
# [INFO:2024-04-18 23:51:30,789:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:30,790:(pipeline_record.py@166 recfldtkn.pipeline_record)]: PatientReminder:'path-../_Data/0-Data_Raw/RawData2023_CVSTDCAug/08_23_2023_PatientReminder.csv' # (340, 3)
# [INFO:2024-04-18 23:51:30,949:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: UserID
# [INFO:2024-04-18 23:51:30,951:(pipeline_record.py@166 recfldtkn.pipeline_record)]: UserDetail:'path-../_Data/0-Data_Raw/RawData2023_CVSTDCAug/08_23_2023_UserDetail.csv' # (8348, 3)
# [INFO:2024-04-18 23:51:31,180:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:31,182:(pipeline_record.py@166 recfldtkn.pipeline_record)]: StepEntry:'path-../_Data/0-Data_Raw/RawData2023_CVSTDCAug/08_23_2023_StepEntry.csv' # (676, 3)
# [INFO:2024-04-18 23:51:31,223:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:31,225:(pipeline_record.py@166 recfldtkn.pipeline_record)]: CurriculumCourseBadgeDetails:'path-../_Data/0-Data_Raw/RawData2023_CVSTDCAug/08_23_2023_CurriculumCourseBadgeDetails.csv' # (783, 3)
# [INFO:2024-04-18 23:51:31,279:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:31,281:(pipeline_record.py@166 recfldtkn.pipeline_record)]: PatientObservationSummary:'path-../_Data/0-Data_Raw/RawData2023_CVSTDCAug/08_23_2023_PatientObservationSummary.csv' # (8303, 3)
# [INFO:2024-04-18 23:51:31,315:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:31,317:(pipeline_record.py@166 recfldtkn.pipeline_record)]: PatientTargetSegment:'path-../_Data/0-Data_Raw/RawData2023_CVSTDCAug/08_23_2023_PatientTargetSegment.csv' # (8303, 3)
# [INFO:2024-04-18 23:51:31,337:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:31,339:(pipeline_record.py@166 recfldtkn.pipeline_record)]: CurriculumQuizResult:'path-../_Data/0-Data_Raw/RawData2023_CVSTDCAug/08_23_2023_CurriculumQuizResult.csv' # (652, 3)
# [INFO:2024-04-18 23:51:31,564:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:31,566:(pipeline_record.py@166 recfldtkn.pipeline_record)]: ELogFoodItem:'path-../_Data/0-Data_Raw/RawData2023_CVSTDCAug/08_23_2023_ELogFoodItem.csv' # (924, 3)
# [INFO:2024-04-18 23:51:31,810:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:31,812:(pipeline_record.py@166 recfldtkn.pipeline_record)]: ELogExerciseEntry:'path-../_Data/0-Data_Raw/RawData2023_CVSTDCAug/08_23_2023_ELogExerciseEntry.csv' # (816, 3)
# [INFO:2024-04-18 23:51:31,833:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:31,835:(pipeline_record.py@166 recfldtkn.pipeline_record)]: PatientHeight:'path-../_Data/0-Data_Raw/RawData2023_CVSTDCAug/08_23_2023_PatientHeight.csv' # (572, 3)
# [INFO:2024-04-18 23:51:31,862:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:31,864:(pipeline_record.py@166 recfldtkn.pipeline_record)]: CurriculumQuizResponse:'path-../_Data/0-Data_Raw/RawData2023_CVSTDCAug/08_23_2023_CurriculumQuizResponse.csv' # (652, 3)
# [INFO:2024-04-18 23:51:31,886:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:31,887:(pipeline_record.py@166 recfldtkn.pipeline_record)]: WeightGoal:'path-../_Data/0-Data_Raw/RawData2023_CVSTDCAug/08_23_2023_WeightGoal.csv' # (379, 3)
# [INFO:2024-04-18 23:51:31,916:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:31,918:(pipeline_record.py@166 recfldtkn.pipeline_record)]: PatientCarbTarget:'path-../_Data/0-Data_Raw/RawData2023_CVSTDCAug/08_23_2023_PatientCarbTarget.csv' # (224, 3)
# [INFO:2024-04-18 23:51:31,949:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: None
# [INFO:2024-04-18 23:51:31,950:(pipeline_record.py@166 recfldtkn.pipeline_record)]: MedPrescriptionDaySchedule:'path-../_Data/0-Data_Raw/RawData2023_CVSTDCAug/08_23_2023_MedPrescriptionDaySchedule.csv' # (0, 3)
# g:\Shared drives\CDHAI-WellDoc\2024-WellDocTest-SPACE\_WellDoc-RFT-WorkSpace\../pipeline\recfldtkn\pipeline_record.py:128: DtypeWarning: Columns (7,26,51,52,53,56,59,77,81,83) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfRaw = pd.read_csv(file_path)
# [INFO:2024-04-18 23:51:32,040:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:32,042:(pipeline_record.py@166 recfldtkn.pipeline_record)]: Patient:'path-../_Data/0-Data_Raw/RawData2023_CVSTDCAug/08_23_2023_Patient.csv' # (8303, 3)
# [INFO:2024-04-18 23:51:32,107:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientId
# [INFO:2024-04-18 23:51:32,108:(pipeline_record.py@166 recfldtkn.pipeline_record)]: WeightMeter:'path-../_Data/0-Data_Raw/RawData2023_CVSTDCAug/08_23_2023_WeightMeter.csv' # (4, 3)
# [INFO:2024-04-18 23:51:32,579:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: UserID
# [INFO:2024-04-18 23:51:32,582:(pipeline_record.py@166 recfldtkn.pipeline_record)]: TDC:'path-../_Data/0-Data_Raw/RawData2023_CVSTDCAug/08_31_2023_DSMQuestionAnswer_CVS_Pull_CVS_TDC.csv' # (8756, 3)
# [INFO:2024-04-18 23:51:33,207:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:33,210:(pipeline_record.py@166 recfldtkn.pipeline_record)]: SleepEntry:'path-../_Data/0-Data_Raw/RawData2023_CVSTDCAug/08_23_2023_SleepEntry.csv' # (783, 3)
# [INFO:2024-04-18 23:51:33,813:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:33,816:(pipeline_record.py@166 recfldtkn.pipeline_record)]: MedAdministration:'path-../_Data/0-Data_Raw/RawData2023_CVSTDCAug/08_23_2023_MedAdministration.csv' # (1055, 3)
# g:\Shared drives\CDHAI-WellDoc\2024-WellDocTest-SPACE\_WellDoc-RFT-WorkSpace\../pipeline\recfldtkn\pipeline_record.py:128: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfRaw = pd.read_csv(file_path)
# [INFO:2024-04-18 23:51:34,641:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:34,645:(pipeline_record.py@166 recfldtkn.pipeline_record)]: RecentElogBGEntry:'path-../_Data/0-Data_Raw/RawData2023_CVSTDCAug/08_23_2023_RecentElogBGEntry.csv' # (373, 3)
# [INFO:2024-04-18 23:51:34,645:(pipeline_record.py@169 recfldtkn.pipeline_record)]: 38 <---- types of dfRec so far
# [INFO:2024-04-18 23:51:34,688:(pipeline_record.py@182 recfldtkn.pipeline_record)]: The patient cohort size: 4256
# [INFO:2024-04-18 23:51:34,718:(976063671.py@54 __main__)]: Save df_Human to: ../_Data/1-Data_RFT\2-RawData2023_CVSTDCAug\PRawRecNum_data
# (4256, 41)
# Saving the dataset (0/1 shards):   0%|          | 0/4256 [00:00<?, ? examples/s]
# [INFO:2024-04-18 23:51:34,814:(976063671.py@25 __main__)]: ==================== RawData2023_CVSDeRxAug: 3 =====================
# [INFO:2024-04-18 23:51:34,814:(976063671.py@26 __main__)]: {'cohort_label': 3, 'cohort_name': 'RawData2023_CVSDeRxAug', 'FolderPath': '../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/'}
# [INFO:2024-04-18 23:51:34,817:(pipeline_record.py@39 recfldtkn.pipeline_record)]: ../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/ <-- FolderPath
# [INFO:2024-04-18 23:51:34,817:(pipeline_record.py@40 recfldtkn.pipeline_record)]: 41 <--- fullfile_list
# [INFO:2024-04-18 23:51:34,817:(pipeline_record.py@91 recfldtkn.pipeline_record)]: =======cohort_label-3: cohort_name-RawData2023_CVSDeRxAug=======
# [INFO:2024-04-18 23:51:34,818:(pipeline_record.py@92 recfldtkn.pipeline_record)]: {'cohort_label': 3, 'cohort_name': 'RawData2023_CVSDeRxAug', 'FolderPath': '../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/'}
# [INFO:2024-04-18 23:51:34,880:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:34,881:(pipeline_record.py@166 recfldtkn.pipeline_record)]: MedAdministration:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_MedAdministration.csv' # (36, 3)
# [INFO:2024-04-18 23:51:34,893:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:34,895:(pipeline_record.py@166 recfldtkn.pipeline_record)]: CustomFood:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_CustomFood.csv' # (26, 3)
# [INFO:2024-04-18 23:51:34,960:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:34,961:(pipeline_record.py@166 recfldtkn.pipeline_record)]: RecentElogBGEntry:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_RecentElogBGEntry.csv' # (33, 3)
# [INFO:2024-04-18 23:51:34,963:(pipeline_record.py@121 recfldtkn.pipeline_record)]: '../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_ImportedMedication.csv' # emtpy file
# [INFO:2024-04-18 23:51:35,010:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:35,011:(pipeline_record.py@166 recfldtkn.pipeline_record)]: ELogCarbsEntry:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_ELogCarbsEntry.csv' # (55, 3)
# [INFO:2024-04-18 23:51:35,027:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:35,028:(pipeline_record.py@166 recfldtkn.pipeline_record)]: CurriculumLessonProgressDetails:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_CurriculumLessonProgressDetails.csv' # (28, 3)
# [INFO:2024-04-18 23:51:35,035:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:35,036:(pipeline_record.py@166 recfldtkn.pipeline_record)]: CurriculumTopicProgressDetails:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_CurriculumTopicProgressDetails.csv' # (28, 3)
# [INFO:2024-04-18 23:51:35,043:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:35,045:(pipeline_record.py@166 recfldtkn.pipeline_record)]: CurriculumQuizResponse:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_CurriculumQuizResponse.csv' # (13, 3)
# [INFO:2024-04-18 23:51:35,081:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:35,083:(pipeline_record.py@166 recfldtkn.pipeline_record)]: SleepEntry:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_SleepEntry.csv' # (44, 3)
# [INFO:2024-04-18 23:51:35,128:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:35,130:(pipeline_record.py@166 recfldtkn.pipeline_record)]: ElogKetoneEntry:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_ElogKetoneEntry.csv' # (51, 3)
# [INFO:2024-04-18 23:51:35,169:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:35,170:(pipeline_record.py@166 recfldtkn.pipeline_record)]: ElogBPEntry:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_ElogBPEntry.csv' # (57, 3)
# [INFO:2024-04-18 23:51:35,191:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:35,192:(pipeline_record.py@166 recfldtkn.pipeline_record)]: PatientReminder:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_PatientReminder.csv' # (24, 3)
# [INFO:2024-04-18 23:51:35,203:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:35,204:(pipeline_record.py@166 recfldtkn.pipeline_record)]: PatientLabTestResult:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_PatientLabTestResult.csv' # (10, 3)
# [INFO:2024-04-18 23:51:35,216:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:35,217:(pipeline_record.py@166 recfldtkn.pipeline_record)]: Patient:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_Patient.csv' # (73, 3)
# [INFO:2024-04-18 23:51:35,224:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:35,225:(pipeline_record.py@166 recfldtkn.pipeline_record)]: PatientTargetSegment:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_PatientTargetSegment.csv' # (73, 3)
# [INFO:2024-04-18 23:51:35,237:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: UserID
# [INFO:2024-04-18 23:51:35,238:(pipeline_record.py@166 recfldtkn.pipeline_record)]: UserDetail:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_UserDetail.csv' # (84, 3)
# [INFO:2024-04-18 23:51:35,245:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:35,247:(pipeline_record.py@166 recfldtkn.pipeline_record)]: PatientBloodGlucoseTargets:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_PatientBloodGlucoseTargets.csv' # (73, 3)
# [INFO:2024-04-18 23:51:35,263:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:35,264:(pipeline_record.py@166 recfldtkn.pipeline_record)]: CurriculumSurveyResponse:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_CurriculumSurveyResponse.csv' # (14, 3)
# [INFO:2024-04-18 23:51:35,265:(pipeline_record.py@121 recfldtkn.pipeline_record)]: '../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_ELogSymptomTracker.csv' # emtpy file
# [INFO:2024-04-18 23:51:35,267:(pipeline_record.py@121 recfldtkn.pipeline_record)]: '../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_FavoriteFood.csv' # emtpy file
# [INFO:2024-04-18 23:51:35,293:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:35,294:(pipeline_record.py@166 recfldtkn.pipeline_record)]: StepEntry:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_StepEntry.csv' # (31, 3)
# [INFO:2024-04-18 23:51:35,296:(pipeline_record.py@121 recfldtkn.pipeline_record)]: '../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_WeightMeter.csv' # emtpy file
# [INFO:2024-04-18 23:51:35,306:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:35,307:(pipeline_record.py@166 recfldtkn.pipeline_record)]: WeightGoal:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_WeightGoal.csv' # (25, 3)
# g:\Shared drives\CDHAI-WellDoc\2024-WellDocTest-SPACE\_WellDoc-RFT-WorkSpace\../pipeline\recfldtkn\pipeline_record.py:128: DtypeWarning: Columns (6,11,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfRaw = pd.read_csv(file_path)
# [INFO:2024-04-18 23:51:36,074:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:36,076:(pipeline_record.py@166 recfldtkn.pipeline_record)]: ElogBGEntry:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_ElogBGEntry.csv' # (68, 3)
# [INFO:2024-04-18 23:51:36,167:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: UserID
# [INFO:2024-04-18 23:51:36,169:(pipeline_record.py@166 recfldtkn.pipeline_record)]: ElogWeightEntry:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_ElogWeightEntry.csv' # (66, 3)
# [INFO:2024-04-18 23:51:36,232:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:36,233:(pipeline_record.py@166 recfldtkn.pipeline_record)]: ELogExerciseEntry:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_ELogExerciseEntry.csv' # (48, 3)
# [INFO:2024-04-18 23:51:36,269:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: UserID
# [INFO:2024-04-18 23:51:36,271:(pipeline_record.py@166 recfldtkn.pipeline_record)]: Rx:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_31_2023_DSMQuestionAnswer_CVS_Pull_De_Rx.csv' # (73, 3)
# [INFO:2024-04-18 23:51:36,287:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:36,289:(pipeline_record.py@166 recfldtkn.pipeline_record)]: ELogCommentEntry:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_ELogCommentEntry.csv' # (56, 3)
# [INFO:2024-04-18 23:51:36,299:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:36,300:(pipeline_record.py@166 recfldtkn.pipeline_record)]: CurriculumQuizResult:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_CurriculumQuizResult.csv' # (13, 3)
# [INFO:2024-04-18 23:51:36,312:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:36,314:(pipeline_record.py@166 recfldtkn.pipeline_record)]: PatientLastExam:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_PatientLastExam.csv' # (3, 3)
# [INFO:2024-04-18 23:51:36,323:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:36,324:(pipeline_record.py@166 recfldtkn.pipeline_record)]: PatientCarbTarget:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_PatientCarbTarget.csv' # (13, 3)
# [INFO:2024-04-18 23:51:36,339:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:36,340:(pipeline_record.py@166 recfldtkn.pipeline_record)]: PatientObservationSummary:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_PatientObservationSummary.csv' # (73, 3)
# [INFO:2024-04-18 23:51:36,360:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:36,361:(pipeline_record.py@166 recfldtkn.pipeline_record)]: CurriculumCourseProgressDetails:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_CurriculumCourseProgressDetails.csv' # (28, 3)
# [INFO:2024-04-18 23:51:36,377:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:36,378:(pipeline_record.py@166 recfldtkn.pipeline_record)]: MedPrescription:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_MedPrescription.csv' # (41, 3)
# [INFO:2024-04-18 23:51:36,519:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:36,521:(pipeline_record.py@166 recfldtkn.pipeline_record)]: ELogFoodItem:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_ELogFoodItem.csv' # (55, 3)
# [INFO:2024-04-18 23:51:36,538:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:36,540:(pipeline_record.py@166 recfldtkn.pipeline_record)]: PatientMeal:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_PatientMeal.csv' # (19, 3)
# [INFO:2024-04-18 23:51:36,562:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:36,564:(pipeline_record.py@166 recfldtkn.pipeline_record)]: PatientMeter:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_PatientMeter.csv' # (63, 3)
# [INFO:2024-04-18 23:51:36,589:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientId
# [INFO:2024-04-18 23:51:36,590:(pipeline_record.py@166 recfldtkn.pipeline_record)]: BPMeter:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_BPMeter.csv' # (41, 3)
# [INFO:2024-04-18 23:51:36,595:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:36,596:(pipeline_record.py@166 recfldtkn.pipeline_record)]: PatientHeight:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_PatientHeight.csv' # (32, 3)
# [INFO:2024-04-18 23:51:36,605:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: PatientID
# [INFO:2024-04-18 23:51:36,607:(pipeline_record.py@166 recfldtkn.pipeline_record)]: CurriculumCourseBadgeDetails:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_CurriculumCourseBadgeDetails.csv' # (15, 3)
# [INFO:2024-04-18 23:51:36,619:(pipeline_record.py@63 recfldtkn.pipeline_record)]: id_column: None
# [INFO:2024-04-18 23:51:36,620:(pipeline_record.py@166 recfldtkn.pipeline_record)]: MedPrescriptionDaySchedule:'path-../_Data/0-Data_Raw/RawData2023_CVSDeRxAug/08_23_2023_MedPrescriptionDaySchedule.csv' # (0, 3)
# [INFO:2024-04-18 23:51:36,620:(pipeline_record.py@169 recfldtkn.pipeline_record)]: 37 <---- types of dfRec so far
# [INFO:2024-04-18 23:51:36,625:(pipeline_record.py@182 recfldtkn.pipeline_record)]: The patient cohort size: 69
# [INFO:2024-04-18 23:51:36,629:(976063671.py@54 __main__)]: Save df_Human to: ../_Data/1-Data_RFT\3-RawData2023_CVSDeRxAug\PRawRecNum_data
# (69, 40)
# Saving the dataset (0/1 shards):   0%|          | 0/69 [00:00<?, ? examples/s]

# %% [markdown]
# # [Part 3] Select Patients with PID

# %%
# from recfldtkn.loadtools import load_ds_rec_and_info
# ds_Human, _ = load_ds_rec_and_info(cohort_args['RecName'], cohort_args)
# df_Human = ds_Human.to_pandas()
# df_Human
# RootID = cohort_args['RootID']
# RawRootID = cohort_args['RawRootID']
# PID_list = [1013405, 1002538, 1022279, 1004432, 1016032, 1032308, 1031363, 1001133, 1007343, 1026067]
# print(PID_list)
# def get_patient_records_Ri(RawRootID_sample, RawRootID, cohort_args):
#     d = {}
#     cohort_config = cohort_args['CohortInfo'][cohort_name]
#     FolderPath = cohort_config['FolderPath']
#     chunk_size = 100000

#     file_list = sorted(os.listdir(FolderPath))
#     file_list = [i for i in file_list if 'csv' in i]
#     for file in file_list:
#         full_file = os.path.join(FolderPath, file)
#         li = [chunk[chunk[RawRootID] == RawRootID_sample] 
#               for chunk in pd.read_csv(full_file, chunksize=chunk_size, low_memory=False)]
#         result = pd.concat(li)
#         logger.info(f'{result.shape}: {file}')
#         if len(result) == 0: continue
#         d[file] = result
        
#     return d

# for PID_sample in PID_list:
#     print('\n======== PID_sample:', PID_sample, '========')
#     PIDInfo_dict = df_Human[df_Human[RootID] == PID_sample].iloc[0].to_dict()
#     RawRootID_sample = PIDInfo_dict[RawRootID]
#     d = get_patient_records_Ri(RawRootID_sample, RawRootID, cohort_args)
#     folder = os.path.join(SPACE['DATA_RAW'], 'patient_sample', str(PID_sample))
#     if os.path.exists(folder) == False: os.makedirs(folder)
#     for file, df in d.items():
#         df.to_csv(os.path.join(folder, file), index = False)
#         print(file, df.shape)
